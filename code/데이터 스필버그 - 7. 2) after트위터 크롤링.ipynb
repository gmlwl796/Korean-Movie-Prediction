# %% [markdown]
# # 5년치 데이터 불러오기

# %%
import pandas as pd

movie = pd.read_csv('./csv2/movie262_name_for_tweeter.csv')
movie
# Out:
#      Unnamed: 0  Unnamed: 0.1          영화명       개봉일       관객수  \
# 0             0             0           명량  20140730  17613682
# 1             1             1           해적  20140806   8666046
# 2             2             2       수상한 그녀  20140122   8657982
# 3             3             3         국제시장  20141217   5345677
# 4             4             4           군도  20140723   4774931
# 5             5             5           타짜  20140903   4015361
# 6             6             6           역린  20140430   3849552
# 7             7             7       신의 한 수  20140703   3566852
# 8             8             8       끝까지 간다  20140529   3450305
# 9             9             9           표적  20140430   2841828
# 10           10            10  나의 사랑 나의 신부  20141008   2141155
# 11           11            11    남자가 사랑할 때  20140122   1979311
# 12           12            12         기술자들  20141224   1778083
# 13           13            13          제보자  20141002   1755181
# ...

# %% [markdown]
# # 개봉일 시간별 분리

# %%
import datetime
temp = movie.개봉일.apply(lambda x: datetime.datetime.strptime(str(x),'%Y%m%d'))

# %%
# 총 영화 갯수 확인 : 스크린 수 100개 이상, 애니메이션 장르 제거한 5년치 한국 상업영화들
print(len(temp))
# Out:
# 262

# %%
ts = temp.dt

# %%
ts_prop = pd.DataFrame({'year':ts.year,
                       'month': ts.month,
                       'day':ts.day,
                       'weekofyear':ts.weekofyear,
                       'dayofyear':ts.dayofyear,
                       'weekday':ts.weekday,
                       'quarter':ts.quarter})

# %% [markdown]
# # 트위터에서 영화 언급수 개봉전 1주일, 개봉후 1주일 크롤링

# %%
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
from selenium.webdriver.firefox.firefox_binary import  FirefoxBinary
from selenium.webdriver.common.desired_capabilities import  DesiredCapabilities
import time
from selenium.webdriver.common.keys import Keys
import datetime as dt

cap = DesiredCapabilities().FIREFOX
cap["marionette"] = True
browser = webdriver.Firefox(capabilities=cap, executable_path="C:/Users/student/Downloads/geckodriver/geckodriver.exe")
browser.get('http://google.com/')

# %%
movie['tweets_after'] = 0
movie['tweets_before'] = 0

# %%
ts_prop.year[0]
# Out:
# 2014

# %%
ts_prop['year']
# Out:
# 0      2014
# 1      2014
# 2      2014
# 3      2014
# 4      2014
# 5      2014
# 6      2014
# 7      2014
# 8      2014
# 9      2014
# 10     2014
# 11     2014
# 12     2014
# 13     2014
# 14     2014
# 15     2014
# 16     2014
# 17     2014
# 18     2014
# 19     2014
# 20     2014
# 21     2014
# 22     2014
# 23     2014
# 24     2014
# 25     2014
# 26     2014
# 27     2014
# 28     2014
# 29     2014
#        ...
# 232    2018
# 233    2018
# 234    2018
# 235    2018
# 236    2018
# 237    2018
# 238    2018
# 239    2018
# 240    2018
# 241    2018
# 242    2018
# 243    2018
# 244    2018
# 245    2018
# 246    2018
# 247    2018
# 248    2018
# 249    2018
# 250    2018
# 251    2018
# 252    2018
# 253    2018
# 254    2018
# 255    2018
# 256    2018
# 257    2018
# 258    2018
# 259    2018
# 260    2018
# 261    2018
# Name: year, Length: 262, dtype: int64

# %%
temp
# Out:
# 0     2014-07-30
# 1     2014-08-06
# 2     2014-01-22
# 3     2014-12-17
# 4     2014-07-23
# 5     2014-09-03
# 6     2014-04-30
# 7     2014-07-03
# 8     2014-05-29
# 9     2014-04-30
# 10    2014-10-08
# 11    2014-01-22
# 12    2014-12-24
# 13    2014-10-02
# 14    2014-01-22
# 15    2014-09-03
# 16    2014-03-13
# 17    2014-08-13
# 18    2014-05-14
# 19    2014-02-20
# 20    2014-11-27
# 21    2014-10-02
# 22    2014-04-10
# 23    2014-10-23
# 24    2014-11-13
# 25    2014-02-13
# 26    2014-12-24
# 27    2014-01-09
# 28    2014-06-04
# 29    2014-11-06
#          ...
# 232   2018-01-31
# 233   2018-07-25
# 234   2018-05-09
# 235   2018-08-29
# 236   2018-09-12
# 237   2018-10-11
# 238   2018-05-17
# 239   2018-03-28
# 240   2018-07-04
# 241   2018-11-07
# 242   2018-09-26
# 243   2018-02-14
# 244   2018-12-05
# 245   2018-06-27
# 246   2018-04-05
# 247   2018-11-15
# 248   2018-03-14
# 249   2018-07-13
# 250   2018-04-19
# 251   2018-07-18
# 252   2018-02-28
# ...

# %%
from datetime import timedelta

date = temp[0] + timedelta(days=7)
date.year
# Out:
# 2014

# %%
temp[0].day
# Out:
# 30

# %%
strtemp = '영화 ' + movie['영화명'][1]
strtemp
# Out:
# '영화 해적'

# %%
totalfreq=[]
for i in range(len(temp)):
    startdate = dt.date(year = temp[i].year, month = temp[i].month, day=temp[i].day)
    datetemp = temp[i] + timedelta(days=1)
    untildate = dt.date(year=datetemp.year, month=datetemp.month, day=datetemp.day)
    datetemp2 = temp[i] + timedelta(days=7)
    enddate = dt.date(year=datetemp2.year, month=datetemp2.month, day=datetemp2.day)

    strtemp = '영화 ' + movie['영화명'][i]
    while not enddate==startdate:
        url='https://twitter.com/search?q='+strtemp+'since%3A'+str(startdate)+'%20until%3A'+str(untildate)+'&amp;amp;amp;amp;amp;amp;lang=eg'
        browser.get(url)
        html = browser.page_source
        soup=BeautifulSoup(html,'html.parser')

        lastHeight = browser.execute_script("return document.body.scrollHeight")
        while True:
                dailyfreq={'Date':startdate}
        #     i=0 i는 페이지수
                wordfreq=0
                tweets=soup.find_all("p", {"class": "TweetTextSize"})
                wordfreq+=len(tweets)

                browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                time.sleep(1)

                newHeight = browser.execute_script("return document.body.scrollHeight")
                print(newHeight)
                if newHeight != lastHeight:
                    html = browser.page_source
                    soup=BeautifulSoup(html,'html.parser')
                    tweets=soup.find_all("p", {"class": "TweetTextSize"})
                    wordfreq=len(tweets)
                else:
                    dailyfreq['Frequency']=wordfreq
                    dailyfreq['Movie']=movie['영화명'][i]
                    wordfreq=0
                    totalfreq.append(dailyfreq)
                    startdate=untildate
                    untildate+=dt.timedelta(days=1)
                    dailyfreq={}
                    break
        #         i+=1
                lastHeight = newHeight
# Out:
# 6548
# 6698
# 6698
# 6682
# 6682
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-5134ad99e98e> in <module>
#      23
#      24                 browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
# ---> 25                 time.sleep(1)
#      26
#      27                 newHeight = browser.execute_script("return document.body.scrollHeight")
#
# KeyboardInterrupt:

# %%
import pandas as pd
df=pd.DataFrame(totalfreq)
df
# Out:
#             Date  Frequency    Movie
# 0     2014-07-30         41       명량
# 1     2014-07-31         39       명량
# 2     2014-08-01         44       명량
# 3     2014-08-02         59       명량
# 4     2014-08-03         49       명량
# 5     2014-08-04         41       명량
# 6     2014-08-05         47       명량
# 7     2014-08-06         42       해적
# 8     2014-08-07         39       해적
# 9     2014-08-08         41       해적
# 10    2014-08-09         39       해적
# 11    2014-08-10         38       해적
# 12    2014-08-11         47       해적
# 13    2014-08-12         43       해적
# 14    2014-01-22         33   수상한 그녀
# 15    2014-01-23         39   수상한 그녀
# 16    2014-01-24         36   수상한 그녀
# 17    2014-01-25         40   수상한 그녀
# 18    2014-01-26         40   수상한 그녀
# 19    2014-01-27         36   수상한 그녀
# 20    2014-01-28         40   수상한 그녀
# 21    2014-12-17         33     국제시장
# 22    2014-12-18         37     국제시장
# 23    2014-12-19         41     국제시장
# ...

# %%
df.to_csv('after_tweets.csv')

# %%
"""
totalfreq=[]
while not enddate==startdate:
    url='https://twitter.com/search?q=%EC%98%81%ED%99%94%20%EA%B3%A4%EC%A7%80%EC%95%94%20since%3A'+str(startdate)+'%20until%3A'+str(untildate)+'&amp;amp;amp;amp;amp;amp;lang=eg'
    browser.get(url)
    html = browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    
    lastHeight = browser.execute_script("return document.body.scrollHeight")
    while True:
            dailyfreq={'Date':startdate}
    #     i=0 i는 페이지수
            wordfreq=0
            tweets=soup.find_all("p", {"class": "TweetTextSize"})
            wordfreq+=len(tweets)

            browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(1)

            newHeight = browser.execute_script("return document.body.scrollHeight")
            print(newHeight)
            if newHeight != lastHeight:
                html = browser.page_source
                soup=BeautifulSoup(html,'html.parser')
                tweets=soup.find_all("p", {"class": "TweetTextSize"})
                wordfreq=len(tweets)
            else:
                dailyfreq['Frequency']=wordfreq
                wordfreq=0
                totalfreq.append(dailyfreq)
                startdate=untildate
                untildate+=dt.timedelta(days=1)
                dailyfreq={}
                break
    #         i+=1
            lastHeight = newHeight
"""

# %% [markdown]
# # 트윗 컬럼 추가

# %%
after = pd.read_csv('./csv2/aftertweets.csv')

# %%
after
# Out:
#       Unnamed: 0        Date  Frequency         Movie
# 0              0  2014-07-30         40            명량
# 1              1  2014-07-31         39            명량
# 2              2  2014-08-01         44            명량
# 3              3  2014-08-02         59            명량
# 4              4  2014-08-03         49            명량
# 5              5  2014-08-04         41            명량
# 6              6  2014-08-05         41            명량
# 7              7  2014-08-06         24  해적: 바다로 간 산적
# 8              8  2014-08-07         15  해적: 바다로 간 산적
# 9              9  2014-08-08         16  해적: 바다로 간 산적
# 10            10  2014-08-09         10  해적: 바다로 간 산적
# 11            11  2014-08-10         10  해적: 바다로 간 산적
# 12            12  2014-08-11         17  해적: 바다로 간 산적
# 13            13  2014-08-12         17  해적: 바다로 간 산적
# 14            14  2014-01-22         33        수상한 그녀
# 15            15  2014-01-23         39        수상한 그녀
# ...

# %% [markdown]
# # 여중생A 컬럼 따로 추가

# %%
import datetime
temp2 = movie.개봉일[[253]].apply(lambda x: datetime.datetime.strptime(str(x),'%Y%m%d'))

# %%
temp2
# Out:
# 253   2018-06-20
# Name: 개봉일, dtype: datetime64[ns]

# %%
ts2 = temp2.dt

# %%
ts_prop2 = pd.DataFrame({'year':ts2.year,
                       'month': ts2.month,
                       'day':ts2.day,
                       'weekofyear':ts2.weekofyear,
                       'dayofyear':ts2.dayofyear,
                       'weekday':ts2.weekday,
                       'quarter':ts2.quarter})

# %%
ts_prop2
# Out:
#      year  month  day  weekofyear  dayofyear  weekday  quarter
# 253  2018      6   20          25        171        2        2

# %%
from datetime import timedelta

date2 = temp2[253] + timedelta(days=7)
date2.year
# Out:
# 2018

# %%
totalfreq=[]

startdate = dt.date(year = temp2[253].year, month = temp[253].month, day=temp[253].day)
datetemp = temp2[253] + timedelta(days=1)
untildate = dt.date(year=datetemp.year, month=datetemp.month, day=datetemp.day)
datetemp2 = temp[253] + timedelta(days=7)
enddate = dt.date(year=datetemp2.year, month=datetemp2.month, day=datetemp2.day)

strtemp = '영화 ' + '여중생A '
while not enddate==startdate:
        url='https://twitter.com/search?q='+strtemp+'since%3A'+str(startdate)+'%20until%3A'+str(untildate)+'&amp;amp;amp;amp;amp;amp;lang=eg'
        browser.get(url)
        html = browser.page_source
        soup=BeautifulSoup(html,'html.parser')

        lastHeight = browser.execute_script("return document.body.scrollHeight")
        while True:
                dailyfreq={'Date':startdate}
        #     i=0 i는 페이지수
                wordfreq=0
                tweets=soup.find_all("p", {"class": "TweetTextSize"})
                wordfreq+=len(tweets)

                browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                time.sleep(1)

                newHeight = browser.execute_script("return document.body.scrollHeight")
                print(newHeight)
                if newHeight != lastHeight:
                    html = browser.page_source
                    soup=BeautifulSoup(html,'html.parser')
                    tweets=soup.find_all("p", {"class": "TweetTextSize"})
                    wordfreq=len(tweets)
                else:
                    dailyfreq['Frequency']=wordfreq
                    dailyfreq['Movie']='여중생A '
                    wordfreq=0
                    totalfreq.append(dailyfreq)
                    startdate=untildate
                    untildate+=dt.timedelta(days=1)
                    dailyfreq={}
                    break
        #         i+=1
                lastHeight = newHeight
# Out:
# 8707
# 9153
# 9153
# 6479
# 6479
# 6486
# 6506
# 6506
# 6044
# 6222
# 6222
# 8173
# 9915
# 9915
# 5215
# 5215
# 4061
# 4061

# %%
import pandas as pd
df2=pd.DataFrame(totalfreq)
df2
# Out:
#          Date  Frequency  Movie
# 0  2018-06-20         37  여중생A
# 1  2018-06-21         34  여중생A
# 2  2018-06-22         40  여중생A
# 3  2018-06-23         38  여중생A
# 4  2018-06-24         42  여중생A
# 5  2018-06-25         24  여중생A
# 6  2018-06-26         25  여중생A

# %%
df2.to_csv('yeo_after_tweets.csv')
