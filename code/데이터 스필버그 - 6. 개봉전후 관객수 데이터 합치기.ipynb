# %%
import pandas as pd

# %%
final_df = pd.read_csv('test_set12.csv', encoding='cp949')
final_df
# Out:
#     Unnamed: 0                영화명            날짜  스크린수   상영횟수            매출액  \
# 0            1             삼국-무영자          개봉이전     1      3      6,879,000
# 1            2             삼국-무영자   개봉1일(12/13)    12     23      1,087,000
# 2            3             삼국-무영자   개봉2일(12/14)    11     22      1,206,500
# 3            4             삼국-무영자   개봉3일(12/15)    16     24      2,005,000
# 4            5             삼국-무영자   개봉4일(12/16)    14     25      1,881,500
# 5            6             삼국-무영자   개봉5일(12/17)    12     22        636,000
# 6            7             삼국-무영자   개봉6일(12/18)    38     47      2,263,500
# 7            8             삼국-무영자   개봉7일(12/19)     1      1         50,000
# 8            9             삼국-무영자   개봉8일(12/20)     4      4         70,000
# 9           10             삼국-무영자   개봉9일(12/21)     3      3         82,000
# 10          11             삼국-무영자  개봉10일(12/22)     4      4         74,000
# ...

# %%
movie_soo = pd.read_csv('movie_soo.csv', encoding = "utf-8")

# %%
final_df  = pd.read_csv("final_df_103.csv", encoding = "utf-8")

# %%
final_df_1 = pd.read_csv('final_df_1.csv', encoding = "utf-8")
final_df_2 = pd.read_csv('final_df_2.csv', encoding = "utf-8")
final_df_4 = pd.read_csv('final_df_4.csv', encoding = "utf-8")
final_df_5 = pd.read_csv('final_df_5.csv', encoding = "utf-8")
final_df_6 = pd.read_csv('final_df_6.csv', encoding = "utf-8")
final_df_7 = pd.read_csv('final_df_7.csv', encoding = "utf-8")
final_df_8 = pd.read_csv('final_df_8.csv', encoding = "utf-8")
final_df_9 = pd.read_csv('final_df_9.csv', encoding = "utf-8")
final_df_10 = pd.read_csv('final_df_10.csv', encoding = "utf-8")
final_df_11 = pd.read_csv('final_df_11.csv', encoding = 'utf-8')
final_df_12 = pd.read_csv('final_df_12.csv', encoding = 'utf-8')
final_df_1['영화명'].unique()
# Out:
# array(['명량', '해적: 바다로 간 산적', '수상한 그녀', '국제시장', '군도: 민란의 시대', '타짜-신의 손',
#        '역린', '신의 한 수', '끝까지 간다', '표적', '나의 사랑 나의 신부', '남자가 사랑할 때', '기술자들',
#        '제보자', '피끓는 청춘', '두근두근 내 인생', '우아한 거짓말', '해무(海霧)', '인간중독',
#        '찌라시: 위험한 소문', '빅매치', '슬로우 비디오', '방황하는 칼날', '우리는 형제입니다', '카트'],
#       dtype=object)

# %%
final_df_12['영화명'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-631e490fcccd> in <module>
# ----> 1 final_df_12['영화명'].unique()
#
# NameError: name 'final_df_12' is not defined

# %%
exception = pd.read_csv('exception.csv', encoding = "utf-8")
exception2 = pd.read_csv('exception2.csv', encoding = "utf-8")
final_df_248_250 = pd.read_csv('final_df_248_250.csv', encoding = "utf-8")
final_df_252_263 = pd.read_csv('final_df_252_263.csv', encoding = "utf-8")

# %%
exception #  번더스  [247:248]
exception2  # [251:252]
# Out:
#    Unnamed: 0     관객수            날짜    누적관객수          누적매출액          매출액  \
# 0           1  76,800   개봉1일(11/15)   76,800    616,136,000  616,136,000
# 1           2  41,901   개봉2일(11/16)  118,701  1,001,107,100  384,971,100
# 2           3  61,237   개봉3일(11/17)  179,938  1,526,733,400  525,626,300
# 3           4  55,130   개봉4일(11/18)  235,068  1,998,118,600  471,385,200
# 4           5  10,996   개봉5일(11/19)  246,064  2,090,671,500   92,552,900
# 5           6  10,530   개봉6일(11/20)  256,594  2,178,525,300   87,853,800
# 6           7   7,493   개봉7일(11/21)  264,087  2,239,994,900   61,469,600
# 7           8   4,970   개봉8일(11/22)  269,057  2,281,735,600   41,740,700
# 8           9   5,293   개봉9일(11/23)  274,350  2,329,285,100   47,549,500
# 9          10  12,407  개봉10일(11/24)  286,757  2,434,554,900  105,269,800
#
#    상영횟수  순위  스크린수             영화명
# 0   698   4   243  번 더 스테이지: 더 무비
# 1   561   4   185  번 더 스테이지: 더 무비
# 2   533   4   200  번 더 스테이지: 더 무비
# ...

# %%
final_df  = pd.read_csv("final_df_103.csv", encoding = "utf-8")
len(final_df['영화명'].unique())
# Out:
# 250

# %%
final_df = final_df[:2716]

# %%
final_df
# Out:
#      Unnamed: 0  Unnamed: 0.1        관객수            날짜      누적관객수  \
# 0             0           NaN     22,500          개봉이전     22,500
# 1             1           NaN    682,701   개봉1일(07/30)    705,201
# 2             2           NaN    705,070   개봉2일(07/31)  1,410,271
# 3             3           NaN    867,437   개봉3일(08/01)  2,277,708
# 4             4           NaN  1,232,529   개봉4일(08/02)  3,510,237
# 5             5           NaN  1,257,380   개봉5일(08/03)  4,767,617
# 6             6           NaN    990,022   개봉6일(08/04)  5,757,639
# 7             7           NaN    869,153   개봉7일(08/05)  6,626,792
# 8             8           NaN    702,887   개봉8일(08/06)  7,329,679
# 9             9           NaN    652,776   개봉9일(08/07)  7,982,455
# 10           10           NaN    690,123  개봉10일(08/08)  8,672,578
# 11           11           NaN     35,335          개봉이전     35,335
# 12           12           NaN    273,445   개봉1일(08/06)    308,780
# ...

# %%
print(movie_soo['영화명'].unique())
print(len(movie_soo['영화명'].unique()))
print(final_df['영화명'].unique())
print(len(final_df['영화명'].unique()))
# Out:
# ['명량' '해적: 바다로 간 산적' '수상한 그녀' '국제시장' '군도: 민란의 시대' '타짜-신의 손' '역린' '신의 한 수'
#  '끝까지 간다' '표적' '나의 사랑 나의 신부' '남자가 사랑할 때' '기술자들' '제보자' '피끓는 청춘' '두근두근 내 인생'
#  '우아한 거짓말' '해무(海霧)' '인간중독' '찌라시: 위험한 소문' '빅매치' '슬로우 비디오' '방황하는 칼날'
#  '우리는 형제입니다' '카트' '관능의 법칙' '상의원' '플랜맨' '우는 남자' '패션왕' '황제를 위하여' '몬스터'
#  '또 하나의 약속' '소녀괴담' '조선미녀삼총사' '마담 뺑덕' '좋은 친구들' '나의 독재자' '하이힐' '레드카펫'
#  '덕수리 5형제' '아빠를 빌려드립니다' '가시' '맨홀' '터널 3D' '설계' '백프로' '베테랑' '암살' '내부자들'
#  '사도' '연평해전' '검은 사제들' '히말라야' '조선명탐정 : 사라진 놉의 딸' '스물' '극비수사' '탐정 : 더 비기닝'
#  '악의 연대기' '강남 1970' '뷰티 인사이드' '오늘의 연애' '쎄시봉' '더 폰' '대호' '차이나타운' '장수상회'
#  '성난 변호사' '간신' '그놈이다' '미쓰 와이프' '허삼관' '살인의뢰' '손님' '열정같은소리하고있네' '특종: 량첸살인기'
#  '서부전선' '헬머니' '위험한 상견례 2' '순수의 시대' '오피스' '협녀, 칼의 기억' '무뢰한' '내 심장을 쏴라'
#  '소수의견' '경성학교: 사라진 소녀들' '치외법권' '극적인 하룻밤' '도리화가' '함정' '조선마술사' '연애의 맛'
#  '내부자들: 디 오리지널' '은밀한 유혹' '나의 절친 악당들' '퇴마: 무녀굴' '돌연변이' '쓰리 썸머 나잇'
#  '미안해 사랑해 고마워' '비밀' '약장수' '타투' '검은손' '부산행' '검사외전' '밀정' '터널' '인천상륙작전' '럭키'
# ...

# %%
final_df.to_csv("final_df_103.csv")

# %%
test_set1
# Out:
#     Unnamed: 0                영화명            날짜  스크린수   상영횟수            매출액  \
# 0            1             삼국-무영자          개봉이전     1      3      6,879,000
# 1            2             삼국-무영자   개봉1일(12/13)    12     23      1,087,000
# 2            3             삼국-무영자   개봉2일(12/14)    11     22      1,206,500
# 3            4             삼국-무영자   개봉3일(12/15)    16     24      2,005,000
# 4            5             삼국-무영자   개봉4일(12/16)    14     25      1,881,500
# 5            6             삼국-무영자   개봉5일(12/17)    12     22        636,000
# 6            7             삼국-무영자   개봉6일(12/18)    38     47      2,263,500
# 7            8             삼국-무영자   개봉7일(12/19)     1      1         50,000
# 8            9             삼국-무영자   개봉8일(12/20)     4      4         70,000
# 9           10             삼국-무영자   개봉9일(12/21)     3      3         82,000
# 10          11             삼국-무영자  개봉10일(12/22)     4      4         74,000
# ...

# %%
final_df
# Out:
#                   영화명            날짜  스크린수   상영횟수            매출액      관객수  \
# 0              삼국-무영자          개봉이전     1      3      6,879,000      763
# 1              삼국-무영자   개봉1일(12/13)    12     23      1,087,000      139
# 2              삼국-무영자   개봉2일(12/14)    11     22      1,206,500      140
# 3              삼국-무영자   개봉3일(12/15)    16     24      2,005,000      699
# 4              삼국-무영자   개봉4일(12/16)    14     25      1,881,500      625
# 5              삼국-무영자   개봉5일(12/17)    12     22        636,000       82
# 6              삼국-무영자   개봉6일(12/18)    38     47      2,263,500      382
# 7              삼국-무영자   개봉7일(12/19)     1      1         50,000        5
# 8              삼국-무영자   개봉8일(12/20)     4      4         70,000       11
# 9              삼국-무영자   개봉9일(12/21)     3      3         82,000       12
# 10             삼국-무영자  개봉10일(12/22)     4      4         74,000       10
# 11            모어 댄 블루          개봉이전    11     30     33,655,400    5,042
# ...

# %%
final_df = final_df.drop('Unnamed: 0.1', axis=1)

# %%
# 뒤죽박죽인 순서 원래대로 바꾸기
final_df2 = final_df[['영화명', '날짜', '스크린수', '상영횟수', '매출액', '관객수', '누적매출액', '누적관객수', '순위']]
final_df2
# Out:
#                   영화명            날짜  스크린수   상영횟수            매출액      관객수  \
# 0              삼국-무영자          개봉이전     1      3      6,879,000      763
# 1              삼국-무영자   개봉1일(12/13)    12     23      1,087,000      139
# 2              삼국-무영자   개봉2일(12/14)    11     22      1,206,500      140
# 3              삼국-무영자   개봉3일(12/15)    16     24      2,005,000      699
# 4              삼국-무영자   개봉4일(12/16)    14     25      1,881,500      625
# 5              삼국-무영자   개봉5일(12/17)    12     22        636,000       82
# 6              삼국-무영자   개봉6일(12/18)    38     47      2,263,500      382
# 7              삼국-무영자   개봉7일(12/19)     1      1         50,000        5
# 8              삼국-무영자   개봉8일(12/20)     4      4         70,000       11
# 9              삼국-무영자   개봉9일(12/21)     3      3         82,000       12
# 10             삼국-무영자  개봉10일(12/22)     4      4         74,000       10
# 11            모어 댄 블루          개봉이전    11     30     33,655,400    5,042
# ...

# %%
# 개봉이전 데이터프레임
before_screen = final_df2.loc[(final_df2['날짜'].str.contains('개봉이전')), :]
before_screen.rename(columns={'관객수': '개봉이전_관객수', 
                              '날짜': '개봉이전_날짜',
                              '누적관객수': '개봉이전_누적관객수',
                             '누적매출액' : '개봉이전_누적매출액',
                              '매출액':'개봉이전_매출액',
                             '상영횟수' : '개봉이전_상영횟수',
                             '순위':'개봉이전_순위',
                             '스크린수':'개봉이전_스크린수'}, inplace=True)
before_screen
# Out:
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#                   영화명 개봉이전_날짜  개봉이전_스크린수 개봉이전_상영횟수     개봉이전_매출액 개봉이전_관객수  \
# 0              삼국-무영자    개봉이전          1         3    6,879,000      763
# 11            모어 댄 블루    개봉이전         11        30   33,655,400    5,042
# 22              헬 페스트    개봉이전          1         1    1,694,000      154
# 33  은혼2: 규칙은 깨라고 있는 것    개봉이전          3         6   11,791,600    1,297
# 43          부다페스트 로큰롤    개봉이전          1         3    1,198,000      147
# 54               스윙키즈    개봉이전        418     1,942  921,820,800  108,706
#
#      개봉이전_누적매출액 개봉이전_누적관객수  개봉이전_순위
# 0     6,879,000        763      NaN
# 11   33,655,400      5,042      NaN
# ...

# %%
# 개봉1일 데이터프레임
day_1_screen = final_df2.loc[(final_df2['날짜'].str.contains('개봉1일')), :]
day_1_screen.rename(columns={'관객수': '개봉1일_관객수', 
                             '날짜': '개봉1일_날짜',
                              '누적관객수': '개봉1일_누적관객수',
                             '누적매출액' : '개봉1일_누적매출액',
                              '매출액':'개봉1일_매출액',
                             '상영횟수' : '개봉1일_상영횟수',
                             '순위':'개봉1일_순위',
                             '스크린수':'개봉1일_스크린수'}, inplace=True)
day_1_screen
# Out:
#                   영화명      개봉1일_날짜  개봉1일_스크린수 개봉1일_상영횟수     개봉1일_매출액 개봉1일_관객수  \
# 1              삼국-무영자  개봉1일(12/13)         12        23    1,087,000      139
# 12            모어 댄 블루  개봉1일(12/12)        128       318   33,008,600    4,049
# 23              헬 페스트  개봉1일(12/13)         82       118    3,118,150      418
# 34  은혼2: 규칙은 깨라고 있는 것  개봉1일(12/13)         45        64    4,597,800      583
# 44          부다페스트 로큰롤  개봉1일(12/20)          6        10      685,500       93
# 55               스윙키즈  개봉1일(12/19)        984     3,669  776,978,000  102,502
#
#        개봉1일_누적매출액 개봉1일_누적관객수  개봉1일_순위
# 1       7,966,000        902     50.0
# 12     66,664,000      9,091     10.0
# 23      4,812,150        572     30.0
# 34     16,389,400      1,880     29.0
# 44      1,883,500        240     53.0
# 55  1,698,798,800    211,208      3.0

# %%
# 개봉2일 데이터프레임
day_2_screen = final_df2.loc[(final_df2['날짜'].str.contains('개봉2일')), :]
day_2_screen.rename(columns={'관객수': '개봉2일_관객수',
                             '날짜': '개봉2일_날짜',
                              '누적관객수': '개봉2일_누적관객수',
                             '누적매출액' : '개봉2일_누적매출액',
                              '매출액':'개봉2일_매출액',
                             '상영횟수' : '개봉2일_상영횟수',
                             '순위':'개봉2일_순위',
                             '스크린수':'개봉2일_스크린수'}, inplace=True)
day_2_screen
# Out:
#                   영화명      개봉2일_날짜  개봉2일_스크린수 개봉2일_상영횟수     개봉2일_매출액 개봉2일_관객수  \
# 2              삼국-무영자  개봉2일(12/14)         11        22    1,206,500      140
# 13            모어 댄 블루  개봉2일(12/13)        132       307   24,895,700    3,055
# 24              헬 페스트  개봉2일(12/14)         72        96    2,844,900      365
# 35  은혼2: 규칙은 깨라고 있는 것  개봉2일(12/14)         48        63    4,113,800      468
# 45          부다페스트 로큰롤  개봉2일(12/21)          6         9      392,800       52
# 56               스윙키즈  개봉2일(12/20)        983     3,519  588,835,200   78,455
#
#        개봉2일_누적매출액 개봉2일_누적관객수  개봉2일_순위
# 2       9,172,500      1,042     53.0
# 13     91,559,700     12,146     11.0
# 24      7,657,050        937     37.0
# 35     20,503,200      2,348     34.0
# 45      2,276,300        292     56.0
# 56  2,287,634,000    289,663      3.0

# %%
# 개봉3일 데이터프레임
day_3_screen = final_df2.loc[(final_df2['날짜'].str.contains('개봉3일')), :]
day_3_screen.rename(columns={'관객수': '개봉3일_관객수',  
                             '날짜': '개봉3일_날짜',
                              '누적관객수': '개봉3일_누적관객수',
                             '누적매출액' : '개봉3일_누적매출액',
                              '매출액':'개봉3일_매출액',
                             '상영횟수' : '개봉3일_상영횟수',
                             '순위':'개봉3일_순위',
                             '스크린수':'개봉3일_스크린수'}, inplace=True)
day_3_screen
# Out:
#                   영화명      개봉3일_날짜  개봉3일_스크린수 개봉3일_상영횟수     개봉3일_매출액 개봉3일_관객수  \
# 3              삼국-무영자  개봉3일(12/15)         16        24    2,005,000      699
# 14            모어 댄 블루  개봉3일(12/14)        124       271   26,606,700    3,085
# 25              헬 페스트  개봉3일(12/15)         66        80    2,828,300      340
# 36  은혼2: 규칙은 깨라고 있는 것  개봉3일(12/15)         47        54    6,367,550      744
# 46          부다페스트 로큰롤  개봉3일(12/22)          6         8      863,450      115
# 57               스윙키즈  개봉3일(12/21)        983     3,478  762,699,869   94,342
#
#        개봉3일_누적매출액 개봉3일_누적관객수  개봉3일_순위
# 3      11,177,500      1,741     28.0
# 14    118,166,400     15,231     12.0
# 25     10,485,350      1,277     34.0
# 36     26,870,750      3,092     27.0
# 46      3,139,750        407     39.0
# 57  3,050,333,869    384,005      3.0

# %%
# 개봉4일 데이터프레임
day_4_screen = final_df2.loc[(final_df2['날짜'].str.contains('개봉4일')), :]
day_4_screen.rename(columns={'관객수': '개봉4일_관객수',  
                             '날짜': '개봉4일_날짜',
                              '누적관객수': '개봉4일_누적관객수',
                             '누적매출액' : '개봉4일_누적매출액',
                              '매출액':'개봉4일_매출액',
                             '상영횟수' : '개봉4일_상영횟수',
                             '순위':'개봉4일_순위',
                             '스크린수':'개봉4일_스크린수'}, inplace=True)
day_4_screen
# Out:
#                   영화명      개봉4일_날짜  개봉4일_스크린수 개봉4일_상영횟수       개봉4일_매출액  \
# 4              삼국-무영자  개봉4일(12/16)         14        25      1,881,500
# 15            모어 댄 블루  개봉4일(12/15)        127       238     28,720,100
# 26              헬 페스트  개봉4일(12/16)         53        59      2,391,500
# 37  은혼2: 규칙은 깨라고 있는 것  개봉4일(12/16)         43        49      4,798,350
# 47          부다페스트 로큰롤  개봉4일(12/23)          5         6        444,500
# 58               스윙키즈  개봉4일(12/22)        860     3,254  1,235,052,383
#
#    개봉4일_관객수     개봉4일_누적매출액 개봉4일_누적관객수  개봉4일_순위
# 4       625     13,059,000      2,366     26.0
# 15    3,292    146,886,500     18,523     13.0
# 26      293     12,876,850      1,570     35.0
# 37      593     31,669,100      3,685     28.0
# 47       62      3,584,250        469     48.0
# 58  141,390  4,285,386,252    525,395      3.0

# %%
# 개봉5일 데이터프레임
day_5_screen = final_df2.loc[(final_df2['날짜'].str.contains('개봉5일')), :]
day_5_screen.rename(columns={'관객수': '개봉5일_관객수',  
                             '날짜': '개봉5일_날짜',
                              '누적관객수': '개봉5일_누적관객수',
                             '누적매출액' : '개봉5일_누적매출액',
                              '매출액':'개봉5일_매출액',
                             '상영횟수' : '개봉5일_상영횟수',
                             '순위':'개봉5일_순위',
                             '스크린수':'개봉5일_스크린수'}, inplace=True)
day_5_screen
# Out:
#                   영화명      개봉5일_날짜  개봉5일_스크린수 개봉5일_상영횟수       개봉5일_매출액  \
# 5              삼국-무영자  개봉5일(12/17)         12        22        636,000
# 16            모어 댄 블루  개봉5일(12/16)        122       221     27,254,000
# 27              헬 페스트  개봉5일(12/17)         54        62      1,275,250
# 38  은혼2: 규칙은 깨라고 있는 것  개봉5일(12/17)         41        52      2,156,200
# 48          부다페스트 로큰롤  개봉5일(12/24)          7        10        753,000
# 59               스윙키즈  개봉5일(12/23)        810     3,001  1,192,813,400
#
#    개봉5일_관객수     개봉5일_누적매출액 개봉5일_누적관객수  개봉5일_순위
# 5        82     13,695,000      2,448     52.0
# 16    3,153    174,140,500     21,676     13.0
# 27      173     14,152,100      1,743     46.0
# 38      274     33,825,300      3,959     34.0
# 48       98      4,337,250        567     41.0
# 59  135,550  5,478,199,652    660,945      3.0

# %%
# 개봉6일 데이터프레임
day_6_screen = final_df2.loc[(final_df2['날짜'].str.contains('개봉6일')), :]
day_6_screen.rename(columns={'관객수': '개봉6일_관객수',  
                             '날짜': '개봉6일_날짜',
                              '누적관객수': '개봉6일_누적관객수',
                             '누적매출액' : '개봉6일_누적매출액',
                              '매출액':'개봉6일_매출액',
                             '상영횟수' : '개봉6일_상영횟수',
                             '순위':'개봉6일_순위',
                             '스크린수':'개봉6일_스크린수'}, inplace=True)
day_6_screen
# Out:
#                   영화명      개봉6일_날짜  개봉6일_스크린수 개봉6일_상영횟수     개봉6일_매출액 개봉6일_관객수  \
# 6              삼국-무영자  개봉6일(12/18)         38        47    2,263,500      382
# 17            모어 댄 블루  개봉6일(12/17)        116       240   16,923,400    2,154
# 28              헬 페스트  개봉6일(12/18)         58        68    1,838,700      243
# 39  은혼2: 규칙은 깨라고 있는 것  개봉6일(12/18)         45        56    2,274,100      310
# 49          부다페스트 로큰롤  개봉6일(12/25)          4         5      724,500       92
# 60               스윙키즈  개봉6일(12/24)        831     2,551  896,843,950  114,277
#
#        개봉6일_누적매출액 개봉6일_누적관객수  개봉6일_순위
# 6      15,958,500      2,830     33.0
# 17    191,063,900     23,830     11.0
# 28     15,990,800      1,986     41.0
# 39     36,099,400      4,269     35.0
# 49      5,061,750        659     47.0
# 60  6,375,043,602    775,222      4.0

# %%
# 개봉7일 데이터프레임
day_7_screen = final_df2.loc[(final_df2['날짜'].str.contains('개봉7일')), :]
day_7_screen.rename(columns={'관객수': '개봉7일_관객수',  
                             '날짜': '개봉7일_날짜',
                              '누적관객수': '개봉7일_누적관객수',
                             '누적매출액' : '개봉7일_누적매출액',
                              '매출액':'개봉7일_매출액',
                             '상영횟수' : '개봉7일_상영횟수',
                             '순위':'개봉7일_순위',
                             '스크린수':'개봉7일_스크린수'}, inplace=True)
day_7_screen
# Out:
#                   영화명      개봉7일_날짜  개봉7일_스크린수 개봉7일_상영횟수       개봉7일_매출액  \
# 7              삼국-무영자  개봉7일(12/19)          1         1         50,000
# 18            모어 댄 블루  개봉7일(12/18)        120       248     18,429,300
# 29              헬 페스트  개봉7일(12/19)          6         6        139,000
# 40  은혼2: 규칙은 깨라고 있는 것  개봉7일(12/19)         15        16        751,650
# 50          부다페스트 로큰롤  개봉7일(12/26)          7         9        663,450
# 61               스윙키즈  개봉7일(12/25)        656     1,856  1,248,260,400
#
#    개봉7일_관객수     개봉7일_누적매출액 개봉7일_누적관객수  개봉7일_순위
# 7         5     16,008,500      2,835     98.0
# 18    2,354    209,493,200     26,184     15.0
# 29       17     16,129,800      2,003     76.0
# 40       94     36,851,050      4,363     46.0
# 50      113      5,725,200        772     40.0
# 61  144,828  7,623,304,002    920,050      5.0

# %%
# 개봉8일 데이터프레임
day_8_screen = final_df2.loc[(final_df2['날짜'].str.contains('개봉8일')), :]
day_8_screen.rename(columns={'관객수': '개봉8일_관객수',  
                             '날짜': '개봉8일_날짜',
                              '누적관객수': '개봉8일_누적관객수',
                             '누적매출액' : '개봉8일_누적매출액',
                              '매출액':'개봉8일_매출액',
                             '상영횟수' : '개봉8일_상영횟수',
                             '순위':'개봉8일_순위',
                             '스크린수':'개봉8일_스크린수'}, inplace=True)
day_8_screen
# Out:
#                   영화명      개봉8일_날짜  개봉8일_스크린수 개봉8일_상영횟수     개봉8일_매출액 개봉8일_관객수  \
# 8              삼국-무영자  개봉8일(12/20)          4         4       70,000       11
# 19            모어 댄 블루  개봉8일(12/19)          5         5      646,000       78
# 30              헬 페스트  개봉8일(12/20)          3         3       25,000        4
# 41  은혼2: 규칙은 깨라고 있는 것  개봉8일(12/20)          6         6      406,000       59
# 51          부다페스트 로큰롤  개봉8일(12/27)          3         3      151,400       22
# 62               스윙키즈  개봉8일(12/26)        608     1,389  323,671,700   54,156
#
#        개봉8일_누적매출액 개봉8일_누적관객수  개봉8일_순위
# 8      16,078,500      2,846     92.0
# 19    210,139,200     26,262     51.0
# 30     16,154,800      2,007    106.0
# 41     37,257,050      4,422     61.0
# 51      5,876,600        794     69.0
# 62  7,946,975,702    974,206      4.0

# %%
# 개봉9일 데이터프레임
day_9_screen = final_df2.loc[(final_df2['날짜'].str.contains('개봉9일')), :]
day_9_screen.rename(columns={'관객수': '개봉9일_관객수', 
                              '날짜': '개봉9일_날짜',
                              '누적관객수': '개봉9일_누적관객수',
                             '누적매출액' : '개봉9일_누적매출액',
                              '매출액':'개봉9일_매출액',
                             '상영횟수' : '개봉9일_상영횟수',
                             '순위':'개봉9일_순위',
                             '스크린수':'개봉9일_스크린수'}, inplace=True)
day_9_screen
# Out:
#                   영화명      개봉9일_날짜  개봉9일_스크린수 개봉9일_상영횟수     개봉9일_매출액 개봉9일_관객수  \
# 9              삼국-무영자  개봉9일(12/21)          3         3       82,000       12
# 20            모어 댄 블루  개봉9일(12/20)          4         4      638,000       79
# 31              헬 페스트  개봉9일(12/21)          5         5       28,000        5
# 42  은혼2: 규칙은 깨라고 있는 것  개봉9일(12/21)          6         6    1,375,400      152
# 52          부다페스트 로큰롤  개봉9일(12/28)          2         2       89,000       14
# 63               스윙키즈  개봉9일(12/27)        631     1,435  297,356,550   39,085
#
#        개봉9일_누적매출액 개봉9일_누적관객수  개봉9일_순위
# 9      16,160,500      2,858     87.0
# 20    210,777,200     26,341     57.0
# 31     16,182,800      2,012    102.0
# 42     38,632,450      4,574     37.0
# 52      5,965,600        808     75.0
# 63  8,244,332,252  1,013,291      5.0

# %%
# 개봉10일 데이터프레임
day_10_screen = final_df2.loc[(final_df2['날짜'].str.contains('개봉10일')), :]
day_10_screen.rename(columns={'관객수': '개봉10일_관객수', 
                               '날짜': '개봉10일_날짜',
                              '누적관객수': '개봉10일_누적관객수',
                             '누적매출액' : '개봉10일_누적매출액',
                              '매출액':'개봉10일_매출액',
                             '상영횟수' : '개봉10일_상영횟수',
                             '순위':'개봉10일_순위',
                             '스크린수':'개봉10일_스크린수'}, inplace=True)
day_10_screen
# Out:
#           영화명      개봉10일_날짜  개봉10일_스크린수 개봉10일_상영횟수    개봉10일_매출액 개봉10일_관객수  \
# 10     삼국-무영자  개봉10일(12/22)           4          4       74,000        10
# 21    모어 댄 블루  개봉10일(12/21)           3          3      654,100        71
# 32      헬 페스트  개봉10일(12/22)           5          5       28,000         5
# 53  부다페스트 로큰롤  개봉10일(12/29)           3          3      316,150        50
# 64       스윙키즈  개봉10일(12/28)         666      1,505  360,835,350    43,230
#
#       개봉10일_누적매출액 개봉10일_누적관객수  개봉10일_순위
# 10     16,234,500       2,868      89.0
# 21    211,431,300      26,412      47.0
# 32     16,210,800       2,017     101.0
# 53      6,281,750         858      54.0
# 64  8,605,167,602   1,056,521       5.0

# %%
before_and_1 = pd.merge(before_screen, day_1_screen, on="영화명", how='outer')
and_2 = pd.merge(before_and_1, day_2_screen, on="영화명", how='outer')
and_3 = pd.merge(and_2, day_3_screen, on="영화명", how='outer')
and_4 = pd.merge(and_3, day_4_screen, on="영화명", how='outer')
and_5 = pd.merge(and_4, day_5_screen, on="영화명", how='outer')
and_6 = pd.merge(and_5, day_6_screen, on="영화명", how='outer')
and_7 = pd.merge(and_6, day_7_screen, on="영화명", how='outer')
and_8 = pd.merge(and_7, day_8_screen, on="영화명", how='outer')
and_9 = pd.merge(and_8, day_9_screen, on="영화명", how='outer')
screen_wide10 = pd.merge(and_9, day_10_screen, on="영화명", how='outer')

# %%
screen_wide10
# Out:
#                  영화명 개봉이전_날짜  개봉이전_스크린수 개봉이전_상영횟수     개봉이전_매출액 개봉이전_관객수  \
# 0             삼국-무영자    개봉이전          1         3    6,879,000      763
# 1            모어 댄 블루    개봉이전         11        30   33,655,400    5,042
# 2              헬 페스트    개봉이전          1         1    1,694,000      154
# 3  은혼2: 규칙은 깨라고 있는 것    개봉이전          3         6   11,791,600    1,297
# 4          부다페스트 로큰롤    개봉이전          1         3    1,198,000      147
# 5               스윙키즈    개봉이전        418     1,942  921,820,800  108,706
#
#     개봉이전_누적매출액 개봉이전_누적관객수  개봉이전_순위      개봉1일_날짜   ...     개봉9일_누적관객수 개봉9일_순위  \
# 0    6,879,000        763      NaN  개봉1일(12/13)   ...          2,858    87.0
# 1   33,655,400      5,042      NaN  개봉1일(12/12)   ...         26,341    57.0
# 2    1,694,000        154      NaN  개봉1일(12/13)   ...          2,012   102.0
# 3   11,791,600      1,297      NaN  개봉1일(12/13)   ...          4,574    37.0
# 4    1,198,000        147      NaN  개봉1일(12/20)   ...            808    75.0
# ...

# %%
movie_soo = pd.read_csv('movie_soo.csv', encoding = "utf-8")

# %%
movie_soo_merged = pd.merge(movie_soo, scer, on="영화명", how='outer')

# %%
print('컬럼갯수:', len(screen_wide10.columns.values.tolist()))
print(screen_wide10.columns.values.tolist())
# Out:
# 컬럼갯수: 89
# ...

# %%
screen_wide10.to_csv("screen_wide10.csv")

# %%
# 스크린수만 추출
only_screen = screen_wide10[['영화명', '개봉이전_스크린수', '개봉1일_스크린수', '개봉2일_스크린수',
              '개봉3일_스크린수', '개봉4일_스크린수', '개봉5일_스크린수',
              '개봉6일_스크린수', '개봉7일_스크린수', '개봉8일_스크린수',
              '개봉9일_스크린수', '개봉10일_스크린수']]

# %%
only_screen
# Out:
#                  영화명 개봉이전_스크린수 개봉1일_스크린수 개봉2일_스크린수 개봉3일_스크린수 개봉4일_스크린수  \
# 0                 명량        37     1,159     1,202     1,300     1,494
# 1       해적: 바다로 간 산적        27       786       795       789       826
# 2             수상한 그녀        19       577       588       613       692
# 3               국제시장        68       931       954       966       914
# 4         군도: 민란의 시대        44     1,250     1,273     1,295     1,394
# 5            타짜-신의 손        28       768       789       827       890
# 6                 역린        25       947       995     1,020     1,054
# 7             신의 한 수       504       664       716       794       780
# 8             끝까지 간다       107       629       625       645       633
# 9                 표적        18       576       610       639       649
# 10       나의 사랑 나의 신부        81       577       587       610       629
# 11         남자가 사랑할 때        11       484       497       511       531
# ...

# %%
only_screen.to_csv("only_screen.csv")

# %%
need = screen_wide10[['영화명', '개봉이전_스크린수', '개봉이전_상영횟수', '개봉이전_관객수',
                      '개봉1일_스크린수', '개봉1일_상영횟수', '개봉1일_관객수',
                      '개봉2일_스크린수', '개봉2일_상영횟수', '개봉2일_관객수',
                     '개봉3일_스크린수', '개봉3일_상영횟수', '개봉3일_관객수']]
need
# Out:
#                  영화명  개봉이전_스크린수 개봉이전_상영횟수 개봉이전_관객수  개봉1일_스크린수 개봉1일_상영횟수  \
# 0             삼국-무영자          1         3      763         12        23
# 1            모어 댄 블루         11        30    5,042        128       318
# 2              헬 페스트          1         1      154         82       118
# 3  은혼2: 규칙은 깨라고 있는 것          3         6    1,297         45        64
# 4          부다페스트 로큰롤          1         3      147          6        10
# 5               스윙키즈        418     1,942  108,706        984     3,669
#
#   개봉1일_관객수  개봉2일_스크린수 개봉2일_상영횟수 개봉2일_관객수  개봉3일_스크린수 개봉3일_상영횟수 개봉3일_관객수
# 0      139         11        22      140         16        24      699
# 1    4,049        132       307    3,055        124       271    3,085
# 2      418         72        96      365         66        80      340
# 3      583         48        63      468         47        54      744
# 4       93          6         9       52          6         8      115
# ...

# %%
need[0:4].to_csv('test_set_four.csv', encoding = 'cp949')

# %%
need = need[0:4]
need.to_csv('test_set4.csv', encoding= 'cp949')

# %%
need
# Out:
#                  영화명  개봉이전_스크린수 개봉이전_상영횟수  개봉1일_스크린수 개봉1일_상영횟수  개봉2일_스크린수  \
# 0             삼국-무영자          1         3         12        23         11
# 1            모어 댄 블루         11        30        128       318        132
# 2              헬 페스트          1         1         82       118         72
# 3  은혼2: 규칙은 깨라고 있는 것          3         6         45        64         48
#
#   개봉2일_상영횟수  개봉3일_스크린수 개봉3일_상영횟수
# 0        22         16        24
# 1       307        124       271
# 2        96         66        80
# 3        63         47        54

# %%
# 필요한 컬럼만 추출
need2 = screen_wide10[['영화명', '개봉4일_스크린수', '개봉5일_스크린수', '개봉6일_스크린수', 
                       '개봉7일_스크린수', '개봉8일_스크린수', '개봉9일_스크린수', '개봉10일_스크린수', 
                     '개봉4일_상영횟수', '개봉5일_상영횟수', '개봉6일_상영횟수',
                      '개봉7일_상영횟수', '개봉8일_상영횟수', '개봉9일_상영횟수', '개봉10일_상영횟수',
                      '개봉4일_관객수', '개봉5일_관객수', '개봉6일_관객수',
                       '개봉7일_관객수', '개봉8일_관객수', '개봉9일_관객수', '개봉10일_관객수',
                      '개봉4일_누적관객수', '개봉5일_누적관객수', '개봉6일_누적관객수', 
                      '개봉7일_누적관객수', '개봉8일_누적관객수', '개봉9일_누적관객수', '개봉10일_누적관객수', 
                    '개봉4일_순위', '개봉5일_순위', '개봉6일_순위',
                      '개봉7일_순위', '개봉8일_순위', '개봉9일_순위',  '개봉10일_순위']]

# %%
print(need2.columns.values.tolist())
# Out:
# ['영화명', '개봉4일_스크린수', '개봉5일_스크린수', '개봉6일_스크린수', '개봉7일_스크린수', '개봉8일_스크린수', '개봉9일_스크린수', '개봉10일_스크린수', '개봉4일_상영횟수', '개봉5일_상영횟수', '개봉6일_상영횟수', '개봉7일_상영횟수', '개봉8일_상영횟수', '개봉9일_상영횟수', '개봉10일_상영횟수', '개봉4일_관객수', '개봉5일_관객수', '개봉6일_관객수', '개봉7일_관객수', '개봉8일_관객수', '개봉9일_관객수', '개봉10일_관객수', '개봉4일_누적관객수', '개봉5일_누적관객수', '개봉6일_누적관객수', '개봉7일_누적관객수', '개봉8일_누적관객수', '개봉9일_누적관객수', '개봉10일_누적관객수', '개봉4일_순위', '개봉5일_순위', '개봉6일_순위', '개봉7일_순위', '개봉8일_순위', '개봉9일_순위', '개봉10일_순위']

# %%
need2.to_csv("need2.csv")

# %%
movie_dayeonjung = pd.merge(movie_soo, screen_wide10, on="영화명", how='outer')
movie_dayeonjung
# Out:
#                  영화명       개봉일           매출액       관객수  스크린수    상영횟수  \
# 0                 명량  20140730  135748398910  17613682  1587  188611
# 1       해적: 바다로 간 산적  20140806   66370682706   8666046   910  133350
# 2             수상한 그녀  20140122   62705348249   8657982  1027  136975
# 3               국제시장  20141217   41089567596   5345677   966   63603
# 4         군도: 민란의 시대  20140723   36988022499   4774931  1394   67237
# 5            타짜-신의 손  20140903   32373120927   4015361   890   80584
# 6                 역린  20140430   29894266890   3849552  1054   83296
# 7             신의 한 수  20140703   28812027456   3566852   794   77109
# 8             끝까지 간다  20140529   27007303900   3450305   645   84875
# 9                 표적  20140430   22256769300   2841828   716   72255
# 10       나의 사랑 나의 신부  20141008   16636404305   2141155   629   69681
# 11         남자가 사랑할 때  20140122   14510222300   1979311   531   41123
# 12              기술자들  20141224   13652480148   1778083   641   24416
# ...

# %%
movie_dayeonjung.columns.values.tolist()
# Out:
# ['영화명',
#  '개봉일',
#  '매출액',
#  '관객수',
#  '스크린수',
#  '상영횟수',
#  '배급사',
#  '영화코드',
#  '장르',
#  '감독',
#  '기사수',
#  '배우',
#  '관객평점',
#  '링크',
#  '개봉이전_날짜',
#  '개봉이전_스크린수',
#  '개봉이전_상영횟수',
#  '개봉이전_매출액',
#  '개봉이전_관객수',
#  '개봉이전_누적매출액',
#  '개봉이전_누적관객수',
#  '개봉이전_순위',
#  '개봉1일_날짜',
#  '개봉1일_스크린수',
#  '개봉1일_상영횟수',
#  '개봉1일_매출액',
#  '개봉1일_관객수',
#  '개봉1일_누적매출액',
#  '개봉1일_누적관객수',
#  '개봉1일_순위',
#  '개봉2일_날짜',
#  '개봉2일_스크린수',
#  '개봉2일_상영횟수',
#  '개봉2일_매출액',
#  '개봉2일_관객수',
#  '개봉2일_누적매출액',
#  '개봉2일_누적관객수',
#  '개봉2일_순위',
#  '개봉3일_날짜',
#  '개봉3일_스크린수',
#  '개봉3일_상영횟수',
#  '개봉3일_매출액',
#  '개봉3일_관객수',
#  '개봉3일_누적매출액',
#  '개봉3일_누적관객수',
#  '개봉3일_순위',
#  '개봉4일_날짜',
#  '개봉4일_스크린수',
#  '개봉4일_상영횟수',
#  '개봉4일_매출액',
#  '개봉4일_관객수',
#  '개봉4일_누적매출액',
#  '개봉4일_누적관객수',
#  '개봉4일_순위',
#  '개봉5일_날짜',
#  '개봉5일_스크린수',
#  '개봉5일_상영횟수',
#  '개봉5일_매출액',
#  '개봉5일_관객수',
#  '개봉5일_누적매출액',
#  '개봉5일_누적관객수',
#  '개봉5일_순위',
#  '개봉6일_날짜',
#  '개봉6일_스크린수',
#  '개봉6일_상영횟수',
#  '개봉6일_매출액',
#  '개봉6일_관객수',
#  '개봉6일_누적매출액',
#  '개봉6일_누적관객수',
# ...

# %%
movie_dayeonjung.to_csv("movie_dayeonjung.csv")

# %%
dayeon_final = pd.merge(movie_dayeonjung, first, on="영화명")

# %%
dayeon_final.to_csv("dayeon_final.csv")

# %%
dayeon_final
# Out:
#      Unnamed: 0                    영화명       개봉일           매출액       관객수  \
# 0             0                     명량  20140730  135748398910  17613682
# 1             1           해적: 바다로 간 산적  20140806   66370682706   8666046
# 2             2                 수상한 그녀  20140122   62705348249   8657982
# 3             3                   국제시장  20141217   41089567596   5345677
# 4             4             군도: 민란의 시대  20140723   36988022499   4774931
# 5             5                타짜-신의 손  20140903   32373120927   4015361
# 6             6                     역린  20140430   29894266890   3849552
# 7             7                 신의 한 수  20140703   28812027456   3566852
# 8             8                 끝까지 간다  20140529   27007303900   3450305
# 9             9                     표적  20140430   22256769300   2841828
# 10           10            나의 사랑 나의 신부  20141008   16636404305   2141155
# 11           11              남자가 사랑할 때  20140122   14510222300   1979311
# ...

# %%
import pandas as pd
from IPython.display import display

pd.options.display.max_columns = None
display(df)
# Out:
#      Unnamed: 0                    영화명       개봉일           매출액       관객수  \
# 0             0                     명량  20140730  135748398910  17613682
# 1             1           해적: 바다로 간 산적  20140806   66370682706   8666046
# 2             2                 수상한 그녀  20140122   62705348249   8657982
# 3             3                   국제시장  20141217   41089567596   5345677
# 4             4             군도: 민란의 시대  20140723   36988022499   4774931
# 5             5                타짜-신의 손  20140903   32373120927   4015361
# 6             6                     역린  20140430   29894266890   3849552
# 7             7                 신의 한 수  20140703   28812027456   3566852
# 8             8                 끝까지 간다  20140529   27007303900   3450305
# 9             9                     표적  20140430   22256769300   2841828
# 10           10            나의 사랑 나의 신부  20141008   16636404305   2141155
# 11           11              남자가 사랑할 때  20140122   14510222300   1979311
# ...

# %%
dayeon_final = dayeon_final.drop('Unnamed: 0', axis=1)
dayeon_final.to_csv('dayeon_final')

# %%
dayeon_final = pd.read_csv("dayeon_final.csv")
dayeon_final
# Out:
#      Unnamed: 0                    영화명       개봉일           매출액       관객수  \
# 0             0                     명량  20140730  135748398910  17613682
# 1             1           해적: 바다로 간 산적  20140806   66370682706   8666046
# 2             2                 수상한 그녀  20140122   62705348249   8657982
# 3             3                   국제시장  20141217   41089567596   5345677
# 4             4             군도: 민란의 시대  20140723   36988022499   4774931
# 5             5                타짜-신의 손  20140903   32373120927   4015361
# 6             6                     역린  20140430   29894266890   3849552
# 7             7                 신의 한 수  20140703   28812027456   3566852
# 8             8                 끝까지 간다  20140529   27007303900   3450305
# 9             9                     표적  20140430   22256769300   2841828
# 10           10            나의 사랑 나의 신부  20141008   16636404305   2141155
# 11           11              남자가 사랑할 때  20140122   14510222300   1979311
# ...

# %%
dayeon_final = pd.read_csv("dayeon_final.csv")
dayeon_final
# Out:
#      Unnamed: 0                    영화명       개봉일           매출액       관객수  \
# 0             0                     명량  20140730  135748398910  17613682
# 1             1           해적: 바다로 간 산적  20140806   66370682706   8666046
# 2             2                 수상한 그녀  20140122   62705348249   8657982
# 3             3                   국제시장  20141217   41089567596   5345677
# 4             4             군도: 민란의 시대  20140723   36988022499   4774931
# 5             5                타짜-신의 손  20140903   32373120927   4015361
# 6             6                     역린  20140430   29894266890   3849552
# 7             7                 신의 한 수  20140703   28812027456   3566852
# 8             8                 끝까지 간다  20140529   27007303900   3450305
# 9             9                     표적  20140430   22256769300   2841828
# 10           10            나의 사랑 나의 신부  20141008   16636404305   2141155
# 11           11              남자가 사랑할 때  20140122   14510222300   1979311
# ...

# %%
dayeon_final.columns.values.tolist()
# Out:
# ['Unnamed: 0',
#  '영화명',
#  '개봉일',
#  '매출액',
#  '관객수',
#  '스크린수',
#  '상영횟수',
#  '배급사',
#  '영화코드',
#  '장르',
#  '감독',
#  '기사수',
#  '배우',
#  '관객평점',
#  '링크',
#  '개봉이전_날짜',
#  '개봉이전_스크린수',
#  '개봉이전_상영횟수',
#  '개봉이전_매출액',
#  '개봉이전_관객수',
#  '개봉이전_누적매출액',
#  '개봉이전_누적관객수',
#  '개봉이전_순위',
#  '개봉1일_날짜',
#  '개봉1일_스크린수',
#  '개봉1일_상영횟수',
#  '개봉1일_매출액',
#  '개봉1일_관객수',
#  '개봉1일_누적매출액',
#  '개봉1일_누적관객수',
#  '개봉1일_순위',
#  '개봉2일_날짜',
#  '개봉2일_스크린수',
#  '개봉2일_상영횟수',
#  '개봉2일_매출액',
#  '개봉2일_관객수',
#  '개봉2일_누적매출액',
#  '개봉2일_누적관객수',
#  '개봉2일_순위',
#  '개봉3일_날짜',
#  '개봉3일_스크린수',
#  '개봉3일_상영횟수',
#  '개봉3일_매출액',
#  '개봉3일_관객수',
#  '개봉3일_누적매출액',
#  '개봉3일_누적관객수',
#  '개봉3일_순위',
#  '개봉4일_날짜',
#  '개봉4일_스크린수',
#  '개봉4일_상영횟수',
#  '개봉4일_매출액',
#  '개봉4일_관객수',
#  '개봉4일_누적매출액',
#  '개봉4일_누적관객수',
#  '개봉4일_순위',
#  '개봉5일_날짜',
#  '개봉5일_스크린수',
#  '개봉5일_상영횟수',
#  '개봉5일_매출액',
#  '개봉5일_관객수',
#  '개봉5일_누적매출액',
#  '개봉5일_누적관객수',
#  '개봉5일_순위',
#  '개봉6일_날짜',
#  '개봉6일_스크린수',
#  '개봉6일_상영횟수',
#  '개봉6일_매출액',
#  '개봉6일_관객수',
#  '개봉6일_누적매출액',
# ...

# %%
totalmovie1 = pd.read_csv('totalmovie_until_152.csv')
totalmovie2= pd.read_csv('totalmovie_from_153.csv')
middle = pd.read_csv('middle.csv')

# %%
first= totalmovie1[['영화명', '기대지수', '노기대지수']]
second = middle[['영화명', '기대지수', '노기대지수']]
third = totalmovie2[['영화명', '기대지수', '노기대지수']]

# %%
total = first.append(second).append(third)
total
# Out:
#                  영화명   기대지수  노기대지수
# 0                 명량  13639   1126
# 1       해적: 바다로 간 산적   4941   1537
# 2             수상한 그녀      0      0
# 3               국제시장  12784   2052
# 4         군도: 민란의 시대  14319   1262
# 5            타짜-신의 손   7157   3757
# 6                 역린   6255    810
# 7             신의 한 수   2407    365
# 8             끝까지 간다   1320    229
# 9                 표적   1717    191
# 10       나의 사랑 나의 신부   8499    921
# 11         남자가 사랑할 때      0      0
# 12              기술자들  24306   2459
# 13               제보자   3728    633
# 14            피끓는 청춘      0      0
# 15         두근두근 내 인생  15718   3747
# 16           우아한 거짓말    163     13
# 17            해무(海霧)   7489   1057
# 18              인간중독   5486   1115
# 19       찌라시: 위험한 소문      0      0
# 20               빅매치   4634    739
# 21           슬로우 비디오   8508    962
# 22           방황하는 칼날   1932    155
# 23         우리는 형제입니다   5789    669
# 24                카트  48999   3049
# 25            관능의 법칙      0      0
# ...

# %%
total.to_csv('expectation.csv')

# %%
expectation = pd.read_csv('expectation.csv', encoding = 'utf-8')
expectation
# Out:
#      Unnamed: 0              영화명   기대지수  노기대지수
# 0             0               명량  13639   1126
# 1             1     해적: 바다로 간 산적   4941   1537
# 2             2           수상한 그녀      0      0
# 3             3             국제시장  12784   2052
# 4             4       군도: 민란의 시대  14319   1262
# 5             5          타짜-신의 손   7157   3757
# 6             6               역린   6255    810
# 7             7           신의 한 수   2407    365
# 8             8           끝까지 간다   1320    229
# 9             9               표적   1717    191
# 10           10      나의 사랑 나의 신부   8499    921
# 11           11        남자가 사랑할 때      0      0
# 12           12             기술자들  24306   2459
# 13           13              제보자   3728    633
# 14           14           피끓는 청춘      0      0
# 15           15        두근두근 내 인생  15718   3747
# 16           16          우아한 거짓말    163     13
# 17           17           해무(海霧)   7489   1057
# 18           18             인간중독   5486   1115
# ...

# %%
movie_dayeonjung
# Out:
#                  영화명       개봉일           매출액       관객수  스크린수    상영횟수  \
# 0                 명량  20140730  135748398910  17613682  1587  188611
# 1       해적: 바다로 간 산적  20140806   66370682706   8666046   910  133350
# 2             수상한 그녀  20140122   62705348249   8657982  1027  136975
# 3               국제시장  20141217   41089567596   5345677   966   63603
# 4         군도: 민란의 시대  20140723   36988022499   4774931  1394   67237
# 5            타짜-신의 손  20140903   32373120927   4015361   890   80584
# 6                 역린  20140430   29894266890   3849552  1054   83296
# 7             신의 한 수  20140703   28812027456   3566852   794   77109
# 8             끝까지 간다  20140529   27007303900   3450305   645   84875
# 9                 표적  20140430   22256769300   2841828   716   72255
# 10       나의 사랑 나의 신부  20141008   16636404305   2141155   629   69681
# 11         남자가 사랑할 때  20140122   14510222300   1979311   531   41123
# 12              기술자들  20141224   13652480148   1778083   641   24416
# ...

# %%
dayeon_final = pd.merge(movie_dayeonjung, total, on="영화명", how='outer')

# %%
dayeon_final
# Out:
#                  영화명       개봉일           매출액       관객수  스크린수    상영횟수  \
# 0                 명량  20140730  135748398910  17613682  1587  188611
# 1       해적: 바다로 간 산적  20140806   66370682706   8666046   910  133350
# 2             수상한 그녀  20140122   62705348249   8657982  1027  136975
# 3               국제시장  20141217   41089567596   5345677   966   63603
# 4         군도: 민란의 시대  20140723   36988022499   4774931  1394   67237
# 5            타짜-신의 손  20140903   32373120927   4015361   890   80584
# 6                 역린  20140430   29894266890   3849552  1054   83296
# 7             신의 한 수  20140703   28812027456   3566852   794   77109
# 8             끝까지 간다  20140529   27007303900   3450305   645   84875
# 9                 표적  20140430   22256769300   2841828   716   72255
# 10       나의 사랑 나의 신부  20141008   16636404305   2141155   629   69681
# 11         남자가 사랑할 때  20140122   14510222300   1979311   531   41123
# 12              기술자들  20141224   13652480148   1778083   641   24416
# ...

# %%
dayeon_final.to_csv('DY_final.csv')

# %%
dayeon_final.columns.values.tolist()
# Out:
# ['영화명',
#  '개봉일',
#  '매출액',
#  '관객수',
#  '스크린수',
#  '상영횟수',
#  '배급사',
#  '영화코드',
#  '장르',
#  '감독',
#  '기사수',
#  '배우',
#  '관객평점',
#  '링크',
#  '개봉이전_날짜',
#  '개봉이전_스크린수',
#  '개봉이전_상영횟수',
#  '개봉이전_매출액',
#  '개봉이전_관객수',
#  '개봉이전_누적매출액',
#  '개봉이전_누적관객수',
#  '개봉이전_순위',
#  '개봉1일_날짜',
#  '개봉1일_스크린수',
#  '개봉1일_상영횟수',
#  '개봉1일_매출액',
#  '개봉1일_관객수',
#  '개봉1일_누적매출액',
#  '개봉1일_누적관객수',
#  '개봉1일_순위',
#  '개봉2일_날짜',
#  '개봉2일_스크린수',
#  '개봉2일_상영횟수',
#  '개봉2일_매출액',
#  '개봉2일_관객수',
#  '개봉2일_누적매출액',
#  '개봉2일_누적관객수',
#  '개봉2일_순위',
#  '개봉3일_날짜',
#  '개봉3일_스크린수',
#  '개봉3일_상영횟수',
#  '개봉3일_매출액',
#  '개봉3일_관객수',
#  '개봉3일_누적매출액',
#  '개봉3일_누적관객수',
#  '개봉3일_순위',
#  '개봉4일_날짜',
#  '개봉4일_스크린수',
#  '개봉4일_상영횟수',
#  '개봉4일_매출액',
#  '개봉4일_관객수',
#  '개봉4일_누적매출액',
#  '개봉4일_누적관객수',
#  '개봉4일_순위',
#  '개봉5일_날짜',
#  '개봉5일_스크린수',
#  '개봉5일_상영횟수',
#  '개봉5일_매출액',
#  '개봉5일_관객수',
#  '개봉5일_누적매출액',
#  '개봉5일_누적관객수',
#  '개봉5일_순위',
#  '개봉6일_날짜',
#  '개봉6일_스크린수',
#  '개봉6일_상영횟수',
#  '개봉6일_매출액',
#  '개봉6일_관객수',
#  '개봉6일_누적매출액',
#  '개봉6일_누적관객수',
# ...
