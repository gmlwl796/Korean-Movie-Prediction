# %%
import pandas as pd

movie_list = pd.read_csv("./csv/movie_total.csv", encoding= 'CP949')
movie_list.head()
# Out:
#     movieCd  audience                movieNm nation    openDate    sales  \
# 0  20180021         1  젊은 아내: 남편 교환의 날 (무삭제)      K  2018-01-22     5000
# 1  20180063       846                     라라      K  2018-02-22  6827500
# 2  20180113       179                 과외의 추억      K  2018-09-07   989000
# 3  20180141       147       정사 : 질투의 덫 - 감독판      K  2018-02-07   808000
# 4  20180142       146           전망 좋은 섹스-감독판      K  2018-01-24   800000
#
#    screen  show  showTm  prdtYear prdtStatNm typeNm      genres directors  \
# 0       1     1      71      2017         개봉     장편      멜로/로맨스        이진
# 1      48    53      96      2018         개봉     장편  멜로/로맨스,드라마       한상희
# 2      20    21      75      2018         개봉     장편      멜로/로맨스      김다니엘
# 3      22    22      64      2017         개봉     장편      멜로/로맨스        이민
# 4      21    21      62      2017         개봉     장편      멜로/로맨스        이민
#
#                                               actors    audits  news
# ...

# %%
import re
text = u'(무삭제)'
parse = re.sub('( )', '', text)
parse
# Out:
# '(무삭제)'

# %%
movie_list.movieNm.replace("-감독판", '', regex = True, inplace = True)
movie_list.movieNm.replace("- 감독판", '', regex = True, inplace = True)
movie_list.movieNm.replace("- 무삭제판", '', regex = True, inplace = True)
movie_list.movieNm.replace("-무삭제판", '', regex = True, inplace = True)
movie_list.movieNm.replace("-완결판", '', regex = True, inplace = True)
movie_list.movieNm.replace("무삭제판", '', regex = True, inplace = True)
movie_list.movieNm.replace("무삭제", '', regex = True, inplace = True)
movie_list.movieNm.replace("감독판", '', regex = True, inplace = True)
movie_list.movieNm.replace("완결판", '', regex = True, inplace = True)

# %%
movie_list
# Out:
#       movieCd  audience               movieNm nation    openDate       sales  \
# 0    20180021         1    젊은 아내: 남편 교환의 날 ()      K  2018-01-22        5000
# 1    20180063       846                    라라      K  2018-02-22     6827500
# 2    20180113       179                과외의 추억      K  2018-09-07      989000
# 3    20180141       147           정사 : 질투의 덫       K  2018-02-07      808000
# 4    20180142       146              전망 좋은 섹스      K  2018-01-24      800000
# 5    20180225       431             동창회의 목적 3      K  2018-02-20     2290000
# 6    20180282       861                  속닥속닥      K  2018-07-13     6912000
# 7    20180401       903                   풀잎들      K  2018-10-25     7222550
# 8    20180761       129               내 친구 엄마      K  2018-03-15      767000
# 9    20180782       128               착한 형수 3      K  2018-06-07      758000
# 10   20180791       182                 엄마 애인      K  2018-01-29     1012000
# ...

# %%
movie_list
# Out:
#       movieCd  audience               movieNm nation    openDate       sales  \
# 0    20180021         1    젊은 아내: 남편 교환의 날 ()      K  2018-01-22        5000
# 1    20180063       846                    라라      K  2018-02-22     6827500
# 2    20180113       179                과외의 추억      K  2018-09-07      989000
# 3    20180141       147           정사 : 질투의 덫       K  2018-02-07      808000
# 4    20180142       146              전망 좋은 섹스      K  2018-01-24      800000
# 5    20180225       431             동창회의 목적 3      K  2018-02-20     2290000
# 6    20180282       861                  속닥속닥      K  2018-07-13     6912000
# 7    20180401       903                   풀잎들      K  2018-10-25     7222550
# 8    20180761       129               내 친구 엄마      K  2018-03-15      767000
# 9    20180782       128               착한 형수 3      K  2018-06-07      758000
# 10   20180791       182                 엄마 애인      K  2018-01-29     1012000
# ...

# %%
import re

for i in range(0, len(movie_list)):
    movie_list.movieNm[i] =  re.sub("[{()''&}]", "", movie_list.movieNm[i])
# Out:
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
movie_list.head()
# Out:
#     movieCd  audience           movieNm nation    openDate    sales  screen  \
# 0  20180021         1  젊은 아내: 남편 교환의 날       K  2018-01-22     5000       1
# 1  20180063       846                라라      K  2018-02-22  6827500      48
# 2  20180113       179            과외의 추억      K  2018-09-07   989000      20
# 3  20180141       147       정사 : 질투의 덫       K  2018-02-07   808000      22
# 4  20180142       146          전망 좋은 섹스      K  2018-01-24   800000      21
#
#    show  showTm  prdtYear prdtStatNm typeNm      genres directors  \
# 0     1      71      2017         개봉     장편      멜로/로맨스        이진
# 1    53      96      2018         개봉     장편  멜로/로맨스,드라마       한상희
# 2    21      75      2018         개봉     장편      멜로/로맨스      김다니엘
# 3    22      64      2017         개봉     장편      멜로/로맨스        이민
# 4    21      62      2017         개봉     장편      멜로/로맨스        이민
#
#                                               actors    audits  news
# ...

# %%
movie_list.head(100)
# Out:
#      movieCd  audience                movieNm nation    openDate        sales  \
# 0   20180021         1       젊은 아내: 남편 교환의 날       K  2018-01-22         5000
# 1   20180063       846                     라라      K  2018-02-22      6827500
# 2   20180113       179                 과외의 추억      K  2018-09-07       989000
# 3   20180141       147            정사 : 질투의 덫       K  2018-02-07       808000
# 4   20180142       146               전망 좋은 섹스      K  2018-01-24       800000
# 5   20180225       431              동창회의 목적 3      K  2018-02-20      2290000
# 6   20180282       861                   속닥속닥      K  2018-07-13      6912000
# 7   20180401       903                    풀잎들      K  2018-10-25      7222550
# 8   20180761       129                내 친구 엄마      K  2018-03-15       767000
# 9   20180782       128                착한 형수 3      K  2018-06-07       758000
# 10  20180791       182                  엄마 애인      K  2018-01-29      1012000
# ...

# %%
movie_list.to_csv("./csv/naemam.csv", index=False)
