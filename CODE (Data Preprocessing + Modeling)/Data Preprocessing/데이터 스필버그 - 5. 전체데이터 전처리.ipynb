# %%
import pandas as pd

movie = pd.read_csv('./csv2/movie.csv')
directors = pd.read_csv("./csv2/directors_final.csv")

# %%
movie.head()
# Out:
#             영화명       개봉일           매출액       관객수  스크린수    상영횟수  \
# 0            명량  20140730  135748398910  17613682  1587  188611
# 1  해적: 바다로 간 산적  20140806   66370682706   8666046   910  133350
# 2        수상한 그녀  20140122   62705348249   8657982  1027  136975
# 3          국제시장  20141217   41089567596   5345677   966   63603
# 4    군도: 민란의 시대  20140723   36988022499   4774931  1394   67237
#
#              배급사      영화코드    장르   감독    기사수                    배우  관객평점  \
# 0      씨제이이앤엠(주)  20129370    사극  김한민  56134          최민식|류승룡|조진웅|  8.46
# 1  롯데쇼핑㈜롯데엔터테인먼트  20136064  어드벤처  이석훈  22656              김남길|손예진|  8.27
# 2      씨제이이앤엠(주)  20131102   드라마  황동혁  61925  심은경|나문희|박인환|성동일|이진욱|  9.00
# 3      씨제이이앤엠(주)  20137048   드라마  윤제균  53038      황정민|김윤진|오달수|정진영|  9.01
# 4         (주)쇼박스  20123501    사극  윤종빈  21502              하정우|강동원|  6.92
#
#                                                   링크
# 0  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# ...

# %%
directors.tail()
# Out:
#      Unnamed: 0 directors  movieNm  peopleCd  prizecount  accumCnt
# 257         257       고경민      데자뷰  20283049           0         0
# 258         258       이성재    비밥바룰라  20289230           0         0
# 259         259       박진영   배반의 장미  20305089           0         0
# 260         260       김정환   해피 투게더  20309609           0         0
# 261         261       강유선  번개맨의 비밀  20311974           0         0

# %%
directors = directors.rename(index=str, columns={"directors": "감독", "movieNm": "영화명"})
directors = directors.drop(['Unnamed: 0'], axis=1)

# %%
movie.tail()
# Out:
#          영화명       개봉일        매출액    관객수  스크린수  상영횟수                배급사  \
# 257      데자뷰  20180530  360833100  48279   536  8123      씨네그루(주)키다리이엔티
# 258    비밥바룰라  20180124  322727200  47565   347  4056      씨네그루(주)키다리이엔티
# 259   배반의 장미  20181018  332232550  41054   457  6932  롯데컬처웍스(주)롯데엔터테인먼트
# 260   해피 투게더  20181115  199344450  26141   240  2312          플레이리스트(주)
# 261  번개맨의 비밀  20181206   46607800   6315   204   441           (주)디스테이션
#
#          영화코드    장르   감독    기사수                        배우  관객평점  \
# 257  20173865  미스터리  고경민   4593              이천희|남규리|이규한|  4.57
# 258  20177473   코미디  이성재   1795           박인환|신구|임현식|윤덕용|  8.99
# 259  20184678   코미디  박진영   3616          김인권|정상훈|손담비|김성철|  5.51
# 260  20189869   드라마  김정환  34161        박성웅|송새벽|최로운|혁|권해효|  7.83
# 261  20183650    가족  강유선    183  서홍석|유수호|최오식|이상철|김수미|김혜원|  9.11
#
#                                                     링크
# 257  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# ...

# %%
movie2 = pd.merge(movie,directors, on=['감독','영화명'])
movie2 = movie2.drop(['peopleCd'], axis=1)
movie2
# Out:
#                  영화명       개봉일           매출액       관객수  스크린수    상영횟수  \
# 0                 명량  20140730  135748398910  17613682  1587  188611
# 1       해적: 바다로 간 산적  20140806   66370682706   8666046   910  133350
# 2             수상한 그녀  20140122   62705348249   8657982  1027  136975
# 3               국제시장  20141217   41089567596   5345677   966   63603
# 4         군도: 민란의 시대  20140723   36988022499   4774931  1394   67237
# 5            타짜-신의 손  20140903   32373120927   4015361   890   80584
# 6                 역린  20140430   29894266890   3849552  1054   83296
# 7             신의 한 수  20140703   28812027456   3566852   794   77109
# 8             끝까지 간다  20140529   27007303900   3450305   645   84875
# 9                 표적  20140430   22256769300   2841828   716   72255
# 10       나의 사랑 나의 신부  20141008   16636404305   2141155   629   69681
# 11         남자가 사랑할 때  20140122   14510222300   1979311   531   41123
# 12              기술자들  20141224   13652480148   1778083   641   24416
# ...

# %%
movie2 = movie2.rename(index=str, columns={"prizecount": "감독수상", "accumCnt": "감독파워"})

# %%
movie2
# Out:
#                  영화명       개봉일           매출액       관객수  스크린수    상영횟수  \
# 0                 명량  20140730  135748398910  17613682  1587  188611
# 1       해적: 바다로 간 산적  20140806   66370682706   8666046   910  133350
# 2             수상한 그녀  20140122   62705348249   8657982  1027  136975
# 3               국제시장  20141217   41089567596   5345677   966   63603
# 4         군도: 민란의 시대  20140723   36988022499   4774931  1394   67237
# 5            타짜-신의 손  20140903   32373120927   4015361   890   80584
# 6                 역린  20140430   29894266890   3849552  1054   83296
# 7             신의 한 수  20140703   28812027456   3566852   794   77109
# 8             끝까지 간다  20140529   27007303900   3450305   645   84875
# 9                 표적  20140430   22256769300   2841828   716   72255
# 10       나의 사랑 나의 신부  20141008   16636404305   2141155   629   69681
# 11         남자가 사랑할 때  20140122   14510222300   1979311   531   41123
# 12              기술자들  20141224   13652480148   1778083   641   24416
# ...

# %%
movie2.to_csv('./csv2/movie2.csv')

# %%
var = pd.read_csv('./csv2/variables.csv')
var.head()
# Out:
#    Unnamed: 0           영화명       개봉일           매출액       관객수  스크린수    상영횟수  \
# 0           0            명량  20140730  135748398910  17613682  1587  188611
# 1           1  해적: 바다로 간 산적  20140806   66370682706   8666046   910  133350
# 2           2        수상한 그녀  20140122   62705348249   8657982  1027  136975
# 3           3          국제시장  20141217   41089567596   5345677   966   63603
# 4           4    군도: 민란의 시대  20140723   36988022499   4774931  1394   67237
#
#              배급사      영화코드    장르  ...       개봉10일_날짜  개봉10일_스크린수 개봉10일_상영횟수  \
# 0      씨제이이앤엠(주)  20129370    사극  ...   개봉10일(08/08)       1,278      7,026
# 1  롯데쇼핑㈜롯데엔터테인먼트  20136064  어드벤처  ...   개봉10일(08/15)         868      4,257
# 2      씨제이이앤엠(주)  20131102   드라마  ...   개봉10일(01/31)         911      3,791
# 3      씨제이이앤엠(주)  20137048   드라마  ...   개봉10일(12/26)         812      3,686
# 4         (주)쇼박스  20123501    사극  ...   개봉10일(08/01)         654      2,699
#
# ...

# %%
var = var.drop(['기사수','배우','관객평점','링크','Unnamed: 0','개봉일','매출액','관객수','스크린수','상영횟수','배급사','장르','감독'], axis = 1)
# Out:
#             영화명      영화코드 개봉이전_날짜  개봉이전_스크린수 개봉이전_상영횟수     개봉이전_매출액 개봉이전_관객수  \
# 0            명량  20129370    개봉이전       37.0       157  172,231,000   22,500
# 1  해적: 바다로 간 산적  20136064    개봉이전       27.0       167  225,478,500   35,335
# 2        수상한 그녀  20131102    개봉이전       19.0       149  195,855,000   31,394
# 3          국제시장  20137048    개봉이전       68.0       236  256,465,000   33,048
# 4    군도: 민란의 시대  20123501    개봉이전       44.0        72  102,601,000   13,964
#
#     개봉이전_누적매출액 개봉이전_누적관객수  개봉이전_순위  ...       개봉10일_날짜 개봉10일_스크린수 개봉10일_상영횟수  \
# 0  172,231,000     22,500      NaN  ...   개봉10일(08/08)      1,278      7,026
# 1  225,478,500     35,335      NaN  ...   개봉10일(08/15)        868      4,257
# 2  195,855,000     31,394      NaN  ...   개봉10일(01/31)        911      3,791
# 3  256,465,000     33,048      NaN  ...   개봉10일(12/26)        812      3,686
# 4  102,601,000     13,964      NaN  ...   개봉10일(08/01)        654      2,699
#
# ...

# %%
var.head()
# Out:
#             영화명      영화코드 개봉이전_날짜  개봉이전_스크린수 개봉이전_상영횟수     개봉이전_매출액 개봉이전_관객수  \
# 0            명량  20129370    개봉이전       37.0       157  172,231,000   22,500
# 1  해적: 바다로 간 산적  20136064    개봉이전       27.0       167  225,478,500   35,335
# 2        수상한 그녀  20131102    개봉이전       19.0       149  195,855,000   31,394
# 3          국제시장  20137048    개봉이전       68.0       236  256,465,000   33,048
# 4    군도: 민란의 시대  20123501    개봉이전       44.0        72  102,601,000   13,964
#
#     개봉이전_누적매출액 개봉이전_누적관객수  개봉이전_순위  ...       개봉10일_날짜 개봉10일_스크린수 개봉10일_상영횟수  \
# 0  172,231,000     22,500      NaN  ...   개봉10일(08/08)      1,278      7,026
# 1  225,478,500     35,335      NaN  ...   개봉10일(08/15)        868      4,257
# 2  195,855,000     31,394      NaN  ...   개봉10일(01/31)        911      3,791
# 3  256,465,000     33,048      NaN  ...   개봉10일(12/26)        812      3,686
# 4  102,601,000     13,964      NaN  ...   개봉10일(08/01)        654      2,699
#
# ...

# %%
var.columns
good = var['기대지수']
bad = var['노기대지수']

# %%
movie3 = pd.merge(movie2,var, on=['영화명','영화코드'])
movie3.head()
# Out:
#             영화명       개봉일           매출액       관객수  스크린수    상영횟수  \
# 0            명량  20140730  135748398910  17613682  1587  188611
# 1  해적: 바다로 간 산적  20140806   66370682706   8666046   910  133350
# 2        수상한 그녀  20140122   62705348249   8657982  1027  136975
# 3          국제시장  20141217   41089567596   5345677   966   63603
# 4    군도: 민란의 시대  20140723   36988022499   4774931  1394   67237
#
#              배급사      영화코드    장르   감독  ...       개봉10일_날짜 개봉10일_스크린수  \
# 0      씨제이이앤엠(주)  20129370    사극  김한민  ...   개봉10일(08/08)      1,278
# 1  롯데쇼핑㈜롯데엔터테인먼트  20136064  어드벤처  이석훈  ...   개봉10일(08/15)        868
# 2      씨제이이앤엠(주)  20131102   드라마  황동혁  ...   개봉10일(01/31)        911
# 3      씨제이이앤엠(주)  20137048   드라마  윤제균  ...   개봉10일(12/26)        812
# 4         (주)쇼박스  20123501    사극  윤종빈  ...   개봉10일(08/01)        654
#
#    개봉10일_상영횟수      개봉10일_매출액  개봉10일_관객수     개봉10일_누적매출액 개봉10일_누적관객수  개봉10일_순위  \
# 0       7,026  5,493,530,692    690,123  66,527,433,508   8,672,578       1.0
# ...

# %%
movie3.to_csv('./csv2/movie3.csv')

# %%
var2 = var.iloc[:,0:34]
var2
# Out:
#                  영화명      영화코드 개봉이전_날짜  개봉이전_스크린수 개봉이전_상영횟수     개봉이전_매출액  \
# 0                 명량  20129370    개봉이전       37.0       157  172,231,000
# 1       해적: 바다로 간 산적  20136064    개봉이전       27.0       167  225,478,500
# 2             수상한 그녀  20131102    개봉이전       19.0       149  195,855,000
# 3               국제시장  20137048    개봉이전       68.0       236  256,465,000
# 4         군도: 민란의 시대  20123501    개봉이전       44.0        72  102,601,000
# 5            타짜-신의 손  20134804    개봉이전       28.0        84  128,406,100
# 6                 역린  20139183    개봉이전       25.0        35   42,921,000
# 7             신의 한 수  20139201    개봉이전      504.0     1,320  589,721,700
# 8             끝까지 간다  20130442    개봉이전      107.0       300  186,449,000
# 9                 표적  20139164    개봉이전       18.0        34   59,479,000
# 10       나의 사랑 나의 신부  20147930    개봉이전       81.0       212  100,795,500
# 11         남자가 사랑할 때  20137043    개봉이전       11.0        29   46,665,000
# ...

# %%
var2.columns
# Out:
# Index(['영화명', '영화코드', '개봉이전_날짜', '개봉이전_스크린수', '개봉이전_상영횟수', '개봉이전_매출액',
#        '개봉이전_관객수', '개봉이전_누적매출액', '개봉이전_누적관객수', '개봉이전_순위', '개봉1일_날짜',
#        '개봉1일_스크린수', '개봉1일_상영횟수', '개봉1일_매출액', '개봉1일_관객수', '개봉1일_누적매출액',
#        '개봉1일_누적관객수', '개봉1일_순위', '개봉2일_날짜', '개봉2일_스크린수', '개봉2일_상영횟수',
#        '개봉2일_매출액', '개봉2일_관객수', '개봉2일_누적매출액', '개봉2일_누적관객수', '개봉2일_순위',
#        '개봉3일_날짜', '개봉3일_스크린수', '개봉3일_상영횟수', '개봉3일_매출액', '개봉3일_관객수',
#        '개봉3일_누적매출액', '개봉3일_누적관객수', '개봉3일_순위'],
#       dtype='object')

# %%
var2 = var2.drop(['개봉이전_날짜','개봉이전_매출액','개봉이전_누적매출액', '개봉이전_누적관객수', '개봉이전_순위', 
                '개봉1일_날짜', '개봉1일_매출액', '개봉1일_누적매출액', '개봉1일_누적관객수', '개봉1일_순위',
                '개봉2일_날짜', '개봉2일_매출액', '개봉2일_누적매출액', '개봉2일_누적관객수', '개봉2일_순위',
                '개봉3일_날짜', '개봉3일_매출액', '개봉3일_누적매출액', '개봉3일_누적관객수', '개봉3일_순위',], axis = 1)
var2.columns
# Out:
# Index(['영화명', '영화코드', '개봉이전_스크린수', '개봉이전_상영횟수', '개봉이전_관객수', '개봉1일_스크린수',
#        '개봉1일_상영횟수', '개봉1일_관객수', '개봉2일_스크린수', '개봉2일_상영횟수', '개봉2일_관객수',
#        '개봉3일_스크린수', '개봉3일_상영횟수', '개봉3일_관객수'],
#       dtype='object')

# %%
movie4 = pd.merge(movie2,var2, on=['영화명','영화코드'])

# %%
movie4.columns
# Out:
# Index(['영화명', '개봉일', '매출액', '관객수', '스크린수', '상영횟수', '배급사', '영화코드', '장르', '감독',
#        '기사수', '배우', '관객평점', '링크', '감독수상', '감독파워', '개봉이전_스크린수', '개봉이전_상영횟수',
#        '개봉이전_관객수', '개봉1일_스크린수', '개봉1일_상영횟수', '개봉1일_관객수', '개봉2일_스크린수',
#        '개봉2일_상영횟수', '개봉2일_관객수', '개봉3일_스크린수', '개봉3일_상영횟수', '개봉3일_관객수'],
#       dtype='object')

# %%
movie4 = movie4.drop(['매출액','스크린수', '상영횟수','영화코드','배우', '관객평점', '링크', '감독'], axis = 1)
movie4.head()
# Out:
#             영화명       개봉일       관객수            배급사    장르    기사수  감독수상  감독파워  \
# 0            명량  20140730  17613682      씨제이이앤엠(주)    사극  56134    28     2
# 1  해적: 바다로 간 산적  20140806   8666046  롯데쇼핑㈜롯데엔터테인먼트  어드벤처  22656     9     4
# 2        수상한 그녀  20140122   8657982      씨제이이앤엠(주)   드라마  61925    27     2
# 3          국제시장  20141217   5345677      씨제이이앤엠(주)   드라마  53038    37     2
# 4    군도: 민란의 시대  20140723   4774931         (주)쇼박스    사극  21502    24     0
#
#    개봉이전_스크린수 개봉이전_상영횟수 개봉이전_관객수 개봉1일_스크린수 개봉1일_상영횟수 개봉1일_관객수 개봉2일_스크린수  \
# 0       37.0       157   22,500     1,159     6,147  682,701     1,202
# 1       27.0       167   35,335       786     3,970  273,445       795
# 2       19.0       149   31,394       577     2,672  142,843       588
# 3       68.0       236   33,048       931     4,444  184,756       954
# 4       44.0        72   13,964     1,250     6,252  551,841     1,273
#
#   개봉2일_상영횟수 개봉2일_관객수 개봉3일_스크린수 개봉3일_상영횟수 개봉3일_관객수
# ...

# %%
movie4['장르'].unique()
# Out:
# array(['사극', '어드벤처', '드라마', '범죄', '액션', '멜로/로맨스', '코미디', '스릴러', '미스터리',
#        '공포(호러)', '판타지', '전쟁', '가족', '다큐멘터리', 'SF', '기타'], dtype=object)

# %%
movie4['배급사'].unique()
# Out:
# array(['씨제이이앤엠(주)', '롯데쇼핑㈜롯데엔터테인먼트', '(주)쇼박스', '롯데쇼핑㈜롯데엔터테인먼트,(주)싸이더스',
#        '씨네그루(주)다우기술', '(주)넥스트엔터테인먼트월드(NEW)', '메가박스중앙(주)플러스엠', 'CGV아트하우스',
#        '이십세기폭스코리아(주)', '(주)리틀빅픽쳐스', '(주)쇼박스,(주)와우픽쳐스', '유나이티드픽처스(주)',
#        '(주)오에이엘', '(주)프레인글로벌', '메가박스중앙(주)플러스엠,(주)레드로버', '(주)인벤트스톤',
#        '(주)박수엔터테인먼트', '(주)팝엔터테인먼트', '(주)마인스 엔터테인먼트',
#        '롯데쇼핑㈜롯데엔터테인먼트,(주)마인스 엔터테인먼트', '(주)리틀빅픽쳐스,(주)이수C&E', '(주)시네마서비스',
#        '판씨네마(주)', '(주)와우픽쳐스,(주)쇼박스', '필라멘트픽쳐스', '(주)리틀빅픽쳐스,(주)인벤트스톤',
#        '(주)대명문화공장,(주)나이너스엔터테인먼트', '와이드 릴리즈(주)', '(주)스톰픽쳐스코리아',
#        '워너브러더스 코리아(주)', '(주)와우픽쳐스', '오퍼스픽쳐스', '(주)콘텐츠 난다긴다',
#        '(주)대명문화공장,(주)리틀빅픽쳐스', '씨네그루(주)키다리이엔티', '(주)스톰픽쳐스코리아,(주)이수C&E',
#        '(주)스톰픽쳐스코리아,TCO(주)더콘텐츠온', '(주)라이크 콘텐츠',
#        '메가박스중앙(주)플러스엠,(주)키위미디어그룹', '롯데쇼핑㈜롯데엔터테인먼트,(주)리틀빅픽쳐스',
#        '오퍼스픽쳐스,CGV아트하우스', 'CGV아트하우스,영화사 풀', '메가박스중앙(주)플러스엠,주식회사 키위컴퍼니',
#        '씨네그루(주)키다리이엔티,주식회사 키위컴퍼니', '(주)이수C&E,(주)스톰픽쳐스코리아',
# ...

# %%
temp = pd.read_csv('./csv2/adult.csv')

temp1 = temp['상영등급']

# %%
movie4['상영등급'] = temp1

# %%
movie4['기대지수'] = good
movie4['비기대지수'] = bad
movie4.head()
# Out:
#             영화명       개봉일       관객수            배급사    장르    기사수  감독수상  감독파워  \
# 0            명량  20140730  17613682      씨제이이앤엠(주)    사극  56134    28     2
# 1  해적: 바다로 간 산적  20140806   8666046  롯데쇼핑㈜롯데엔터테인먼트  어드벤처  22656     9     4
# 2        수상한 그녀  20140122   8657982      씨제이이앤엠(주)   드라마  61925    27     2
# 3          국제시장  20141217   5345677      씨제이이앤엠(주)   드라마  53038    37     2
# 4    군도: 민란의 시대  20140723   4774931         (주)쇼박스    사극  21502    24     0
#
#    개봉이전_스크린수 개봉이전_상영횟수  ...  개봉1일_관객수 개봉2일_스크린수 개봉2일_상영횟수 개봉2일_관객수 개봉3일_스크린수  \
# 0       37.0       157  ...   682,701     1,202     6,258  705,070     1,300
# 1       27.0       167  ...   273,445       795     3,932  254,862       789
# 2       19.0       149  ...   142,843       588     2,740  138,364       613
# 3       68.0       236  ...   184,756       954     4,491  198,552       966
# 4       44.0        72  ...   551,841     1,273     6,374  419,127     1,295
#
#   개봉3일_상영횟수 개봉3일_관객수     상영등급   기대지수 비기대지수
# ...

# %%
holiday_dict = {"01":"방학","02":"방학","03":"일반", "04":"일반", "05":"일반", "06":"일반", "07":"방학", "08":"방학", "09":"일반","10":"일반","11":"일반","12":"일반"}
holiday_dict2 = {"01":1,"02":1,"03":0, "04":0, "05":0, "06":0, "07":1, "08":1, "09":0,"10":0,"11":0,"12":0}
season_dict = {"01":"겨울","02":"겨울","03":"봄", "04":"봄", "05":"봄", "06":"여름", "07":"여름", "08":"여름", "09":"가을","10":"가을","11":"가을","12":"겨울"}
season_dict2 = {"01":4,"02":4,"03":1, "04":1, "05":1, "06":2, "07":2, "08":2, "09":3,"10":3,"11":3,"12":4}

# %%
movie4.Date = movie4.개봉일.astype(str)
movie4['holiday']= movie4.Date.str[4:6].map(holiday_dict2)
movie4['season']= movie4.Date.str[4:6].map(season_dict2)
movie4
# Out:
#                  영화명       개봉일       관객수                              배급사  \
# 0                 명량  20140730  17613682                        씨제이이앤엠(주)
# 1       해적: 바다로 간 산적  20140806   8666046                    롯데쇼핑㈜롯데엔터테인먼트
# 2             수상한 그녀  20140122   8657982                        씨제이이앤엠(주)
# 3               국제시장  20141217   5345677                        씨제이이앤엠(주)
# 4         군도: 민란의 시대  20140723   4774931                           (주)쇼박스
# 5            타짜-신의 손  20140903   4015361            롯데쇼핑㈜롯데엔터테인먼트,(주)싸이더스
# 6                 역린  20140430   3849552                    롯데쇼핑㈜롯데엔터테인먼트
# 7             신의 한 수  20140703   3566852                           (주)쇼박스
# 8             끝까지 간다  20140529   3450305                           (주)쇼박스
# 9                 표적  20140430   2841828                        씨제이이앤엠(주)
# 10       나의 사랑 나의 신부  20141008   2141155                      씨네그루(주)다우기술
# 11         남자가 사랑할 때  20140122   1979311              (주)넥스트엔터테인먼트월드(NEW)
# ...

# %%
movie4.to_csv('./csv2/movie4_읽기전용.csv', encoding='CP949')
movie4.to_csv('./csv2/movie4.csv')

# %%
moviebae = pd.DataFrame(movie4.배급사)
moviebae2 = pd.DataFrame(movie4.배급사.unique())

# %%
moviebae.to_csv('./csv2/배급사.csv', encoding='CP949')
moviebae2.to_csv('./csv2/배급사2.csv', encoding='CP949')
