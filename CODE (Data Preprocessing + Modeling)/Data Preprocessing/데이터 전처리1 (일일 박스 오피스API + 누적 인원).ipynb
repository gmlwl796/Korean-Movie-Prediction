# %% [markdown]
# # 일일 박스오피스 API를 이용
# ## 2018년01월11일 ~ 2018년11월3일까지의 개봉영화와 누적 관람객 수 찾기

# %%
import pandas as pd
import datetime
import requests

key1 = '93745210481f71d608b0ecd18fc8a7e9'

def crawl_data(start_date, end_date, keys=key1):
    final_list = []
    url = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json'

    # 아래 Y,N,K,F가 다양성/상업, 국내/해외 영화를 각각 정의해준다.
    for single_date in pd.date_range(start_date, end_date):
        for multi, rep in zip(["N"], ["K"]):
            payload = {
                'key': keys,
                'targetDt': single_date.strftime('%Y%m%d'),
                'itemPerPage': '10',
                'multiMovieYn': multi,
                'repNationCd': rep
            }

            req = requests.get(url, params=payload)

            ## 여기서 리스트 형태로 저장하는 이유는 데이터프레임에 하나의 row로 인식되어 들어가게 하기 위함이다.
            for item in req.json()['boxOfficeResult']['dailyBoxOfficeList']:
                temp_list = []
                key_list = []
                for key, value in item.items():
                    key_list.append(key)
                    temp_list.append(value)

                temp_list.append(single_date)
                key_list.append('CurrentDate')

                temp_list.append(multi)
                key_list.append('multi')

                temp_list.append(rep)
                key_list.append('Nation')

                ## 위에서 temp_list에는 내용이, key_list에는 헤더가 담겼다.
                ## 이제 final_list에 내용을 담아준다. 사실 key_list는 한 번만 담아도 되지만 그냥 저렇게 두었다.
                final_list.append(temp_list)

    ## 마지막으로 final_list에 담긴 내용들을 데이터프레임으로 반환한다.
    return pd.DataFrame(final_list, columns=key_list)


movie = crawl_data("20180101", "20181130", keys=key1)

# %%
movie.head()
# Out:
#   rnum rank rankInten rankOldAndNew   movieCd          movieNm      openDt  \
# 0    1    1         0           OLD  20150976        신과함께-죄와 벌  2017-12-20
# 1    2    2         0           OLD  20170590             1987  2017-12-27
# 2    3    3         0           OLD  20170402              강철비  2017-12-14
# 3    4    4         0           OLD  20174846  뽀로로 극장판 공룡섬 대모험  2017-12-07
# 4    5    5         1           OLD  20176769            광인옥한흠  2017-12-28
#
#      salesAmt salesShare  salesInten  ...       salesAcc audiCnt audiInten  \
# 0  7715346100       58.3  -852824100  ...    76065842532  916689   -107268
# 1  4460740100       33.7  -224343200  ...    19714744137  531520    -28526
# 2   944300600        7.1   -48744300  ...    32939198166  114310     -6536
# 3   109207600        0.8       60400  ...     5958096200   13750        -3
# 4     3171000        0.0     2273500  ...       15236500     372       262
#
#   audiChange  audiAcc scrnCnt showCnt CurrentDate multi Nation
# 0      -10.5  9456184    1644    7957  2018-01-01     N      K
# 1       -5.1  2473597    1097    4982  2018-01-01     N      K
# 2       -5.4  4128603     602    1451  2018-01-01     N      K
# 3          0   787493     195     270  2018-01-01     N      K
# 4      238.2     2009      11      12  2018-01-01     N      K
#
# [5 rows x 21 columns]

# %%
# 불필요한 열 데이터 삭제
del movie["rank"]
del movie['rnum']
del movie['rankInten']
del movie['rankOldAndNew']
del movie['salesInten']
del movie['salesChange']
del movie['audiInten']
del movie['audiChange']
del movie['salesShare']
del movie['salesAmt']

# %%
movie.head() # 열 삭제 확인
# Out:
#     movieCd          movieNm      openDt     salesAcc audiCnt  audiAcc  \
# 0  20150976        신과함께-죄와 벌  2017-12-20  76065842532  916689  9456184
# 1  20170590             1987  2017-12-27  19714744137  531520  2473597
# 2  20170402              강철비  2017-12-14  32939198166  114310  4128603
# 3  20174846  뽀로로 극장판 공룡섬 대모험  2017-12-07   5958096200   13750   787493
# 4  20176769            광인옥한흠  2017-12-28     15236500     372     2009
#
#   scrnCnt showCnt CurrentDate multi Nation
# 0    1644    7957  2018-01-01     N      K
# 1    1097    4982  2018-01-01     N      K
# 2     602    1451  2018-01-01     N      K
# 3     195     270  2018-01-01     N      K
# 4      11      12  2018-01-01     N      K

# %% [markdown]
# - boxofficeType : 문자열	박스오피스 종류를 출력합니다.
# - showRange	    : 문자열	박스오피스 조회 일자를 출력합니다.
# - movieCd	    : 문자열	영화의 대표코드를 출력합니다.
# - movieNm	    : 문자열	영화명(국문)을 출력합니다.
# - openDt	    : 문자열	영화의 개봉일을 출력합니다.
# - salesAcc	    : 문자열	누적매출액을 출력합니다.
# - audiCnt	    : 문자열	해당일의 관객수를 출력합니다.
# - audiAcc	    : 문자열	누적관객수를 출력합니다.
# - scrnCnt	    : 문자열	해당일자에 상영한 스크린수를 출력합니다.
# - showCnt	    : 문자열	해당일자에 상영된 횟수를 출력합니다.

# %%
movie[movie['movieNm'] == '1987']
# Out:
#        movieCd movieNm      openDt     salesAcc audiCnt  audiAcc scrnCnt  \
# 1     20170590    1987  2017-12-27  19714744137  531520  2473597    1097
# 8     20170590    1987  2017-12-27  21358190737  217249  2690846    1063
# 18    20170590    1987  2017-12-27  22687596737  174991  2865837     964
# 28    20170590    1987  2017-12-27  23928564037  163434  3029271     986
# 36    20170590    1987  2017-12-27  25636682734  202194  3231465    1012
# 43    20170590    1987  2017-12-27  29308960032  436764  3668229    1094
# 53    20170590    1987  2017-12-27  32848232932  421162  4089391    1067
# 60    20170590    1987  2017-12-27  34216684732  179977  4269368    1012
# 70    20170590    1987  2017-12-27  35549886032  175795  4445163    1052
# 80    20170590    1987  2017-12-27  36814820232  166737  4611900    1080
# 90    20170590    1987  2017-12-27  37912714832  143893  4755793     957
# 100   20170590    1987  2017-12-27  39502561286  186221  4942014     995
# 110   20170590    1987  2017-12-27  43183726345  434063  5376077    1103
# 120   20170590    1987  2017-12-27  46645839945  410882  5786959    1122
# 129   20170590    1987  2017-12-27  47624421645  128997  5915956    1015
# 138   20170590    1987  2017-12-27  48502341145  116339  6032295    1042
# 149   20170590    1987  2017-12-27  49191167945   90628  6122923     755
# 159   20170590    1987  2017-12-27  49799015345   80291  6203214     745
# 169   20170590    1987  2017-12-27  50577182545   91395  6294609     745
# 179   20170590    1987  2017-12-27  52261279545  198201  6492810     714
# 189   20170590    1987  2017-12-27  53739655745  175486  6668296     708
# 90      3840  2018-01-11     N      K
# 100     4045  2018-01-12     N      K
# 110     4584  2018-01-13     N      K
# 120     4516  2018-01-14     N      K
# 129     4222  2018-01-15     N      K
# 138     4239  2018-01-16     N      K
# 149     2901  2018-01-17     N      K
# 159     2833  2018-01-18     N      K
# 169     2842  2018-01-19     N      K
# 179     2744  2018-01-20     N      K
# 189     2642  2018-01-21     N      K
# 199     2599  2018-01-22     N      K
# 210     2540  2018-01-23     N      K
# 220     1816  2018-01-24     N      K
# 230     1706  2018-01-25     N      K
# 240     1733  2018-01-26     N      K
# 250     1666  2018-01-27     N      K
# 260     1615  2018-01-28     N      K
# 270     1621  2018-01-29     N      K
# 280     1611  2018-01-30     N      K
# ...      ...         ...   ...    ...
# 301      668  2018-02-01     N      K
# 311      685  2018-02-02     N      K
# 321      636  2018-02-03     N      K
# 331      641  2018-02-04     N      K
# 341      706  2018-02-05     N      K
# 351      707  2018-02-06     N      K
# 361      710  2018-02-07     N      K
# 372      265  2018-02-08     N      K
# 382      279  2018-02-09     N      K
# 393      260  2018-02-10     N      K
# 403      243  2018-02-11     N      K
# 413      265  2018-02-12     N      K
# 424      270  2018-02-13     N      K
# 436       18  2018-02-14     N      K
# 444       14  2018-02-15     N      K
# 453       13  2018-02-16     N      K
# 463       14  2018-02-17     N      K
# 474       13  2018-02-18     N      K
# 485       98  2018-02-19     N      K
# 496      100  2018-02-20     N      K
# 506       92  2018-02-21     N      K
# 514       82  2018-02-22     N      K
# 525       77  2018-02-23     N      K
# 535       79  2018-02-24     N      K
# 544       75  2018-02-25     N      K
# 556       72  2018-02-26     N      K
# 567       78  2018-02-27     N      K
# 575       18  2018-02-28     N      K
# 656        2  2018-03-08     N      K
# 2116       1  2018-08-03     N      K
#
# [61 rows x 11 columns]

# %% [markdown]
# ##### 아무래도 일일 영화데이터를 스크롤링한 것이므로 데이터가 중복되고 누적됨을 알 수 있음.
# 우리는 누적 관객 수만 구하면 되므로 마지막 아이만 뽑아야함

# %% [markdown]
# <hr>
#
# # 최근 누적합계 찾기
# ##### 일간 데이터이므로 데이터 중복이 일어남.
# ##### 그래서 가장 최근의 누적 합계를 찾기 위해 쿼리 작성

# %%
# int형으로 묶어서 누적 구하기
movie.showCnt = movie.showCnt.astype(int)
movie.audiCnt = movie.audiCnt.astype(int)
movie.scrnCnt = movie.scrnCnt.astype(int)

# %%
movie_group = movie.groupby(['movieCd'])
recent = pd.DataFrame({
                    'movieNm' : movie_group['movieNm'].max(),
                    'screen' : movie_group['scrnCnt'].sum(),
                    'show' : movie_group['showCnt'].sum(),
                    'audience' : movie_group['audiAcc'].max(),
                    'sales' : movie_group['salesAcc'].max(),
                    'nation' : movie_group['Nation'].max(),
                    'openDate' : movie_group['openDt'].min()
                    }).reset_index()

recent
# Out:
#       movieCd  audience                           movieNm nation    openDate  \
# 0    19460021       494                              자유만세      K  1946-10-21
# 354  20189761       503               터닝메카드W: 반다인의 비밀 특별판      K  2018-02-08
# 355  20189781         3                정사 : 바람난 유부녀들 무삭제판      K  2018-01-15
# 356  20189783    954070                               챔피언      K  2018-05-01
# 357  20189804       100                                설날      K
# 358  20189862       120                      감금의 시간 2 무삭제      K  2018-01-17
# 359  20189869      7181                            해피 투게더      K  2018-11-15
# 360  20189902         1                 파도 여인 그리고 탱고 무삭제판      K  2018-01-12
# 361  20189974        93          오렌지필름 기획전 - do not reply      K
#
#            sales  screen   show
# 0         988000       3     24
# 1        3045000       8     35
# 2        4175000       2      8
# 3        8234000       2      8
# 4         475000       1      3
# 5        3990000       1      1
# 6         943000       2      2
# 7         586000       2      8
# 8        6040000       1      4
# 9        2619000       1      4
# 10        376000       1      4
# 11        456000       2      6
# 12       1768000       1      4
# 13       1086000       1      1
# 14        729000      52     56
# 15         49000       1      1
# 16      32575000       3      3
# 17      14839500       8      8
# 18      24647997     112    163
# 19   20495179593      18     18
# 20        540000       1      1
# 21        194000       1      1
# 22        263000       1      1
# 23        860000      15     24
# 24       1656500       2      2
# 25        972500       2      2
# 26   14855497000      38     38
# 27      11388000       2      8
# 28       6715000       2      8
# 29   81026991000       2      2
# ..           ...     ...    ...
# 332       214000       1      1
# 333        89000       2      2
# 334       230000       1      1
# 335       291000       1      1
# 336       147000       1      1
# 337        88000       1      1
# 338     90701800   14321  41885
# 339      3339200       7      8
# 340       776000       7     20
# 341       186000       1      1
# 342       666000       1      1
# 343       964000      20     20
# 344       963000      20     20
# 345       905000      20     20
# 346         6000       1      1
# 347     69957200     414    760
# 348       105000       1      1
# 349        50000       1      1
# 350    821271100    2159   5310
# 351       804000      21     21
# 352       765000      20     20
# 353     91252000    2130   2452
# 354     78820700     906   1561
# 355         6000       3      3
# 356   9471138230   12553  47356
# 357       700000       1      1
# 358       701000      20     20
# 359     90207250    1645   2288
# 360         5000       1      1
# 361       601000       1      1
#
# [362 rows x 8 columns]

# %%
recent[recent['movieNm'] == '1987']
# Out:
#      movieCd audience movieNm nation    openDate        sales  screen    show
# 86  20170590  7231830    1987      K  2017-12-27  58166910145   30678  110587

# %% [markdown]
# - 행이 하나만 나오고 다 합쳐짐

# %% [markdown]
# # 이상치 & 결측치 제거
#
# - 재상영 영화를 제거하기 위해서 'movieCd'가 2018로 시작하는 row로만 구성
# - 또한, 영화개봉일(openDate)이 공백인 것을 제외하기

# %%
temp = pd.DataFrame(columns=('movieCd', 'audience', 'movieNm', 'nation', 'openDate', 'sales', 'screen','show'))
movietemp = pd.DataFrame(columns=('movieCd', 'audience', 'movieNm', 'nation', 'openDate', 'sales', 'screen','show'))

# %% [markdown]
# #### 1. movieCd가 2018로 시작하는 아이만 movietemp 데이터프레임에 넣어준다

# %%
for i in range(0, len(recent)):
    if '2018' in recent.iloc[i].movieCd:
        temp = recent.iloc[i]
        movietemp = movietemp.append(temp)

# %%
movietemp.head()
# Out:
#       movieCd audience                movieNm nation    openDate    sales  \
# 152  20180021        1  젊은 아내: 남편 교환의 날 (무삭제)      K  2018-01-22     5000
# 153  20180063      846                     라라      K  2018-02-22  6827500
# 154  20180085      123                 초승달의 집      K               615000
# 155  20180113      179                 과외의 추억      K  2018-09-07   989000
# 156  20180141      147       정사 : 질투의 덫 - 감독판      K  2018-02-07   808000
#
#      screen  show
# 152     1.0   1.0
# 153    48.0  53.0
# 154     1.0   1.0
# 155    20.0  21.0
# 156    22.0  22.0

# %% [markdown]
# - 값을 보면, movieCd가 2018로 시작하는 애로 구성되어 있는 것을 알 수 있다.
# - index값이 섞여있으므로 정리해줘야함

# %%
movietemp = movietemp.reset_index(drop=True)
movietemp.head()
# Out:
#     movieCd audience                movieNm nation    openDate    sales  \
# 0  20180021        1  젊은 아내: 남편 교환의 날 (무삭제)      K  2018-01-22     5000
# 1  20180063      846                     라라      K  2018-02-22  6827500
# 2  20180085      123                 초승달의 집      K               615000
# 3  20180113      179                 과외의 추억      K  2018-09-07   989000
# 4  20180141      147       정사 : 질투의 덫 - 감독판      K  2018-02-07   808000
#
#    screen  show
# 0     1.0   1.0
# 1    48.0  53.0
# 2     1.0   1.0
# 3    20.0  21.0
# 4    22.0  22.0

# %% [markdown]
# index 정렬됨

# %%
# 중복값 없음 확인
movietemp[movietemp['movieNm'] == '덕구']
# Out:
#      movieCd audience movieNm nation    openDate     sales  screen     show
# 33  20181561     9453      덕구      K  2018-04-05  88620000  7696.0  19030.0

# %% [markdown]
# #### 2. openDate가 공백인 것 제외하고 다시 데이터프레임 구성

# %%
tmp = pd.DataFrame(columns=('movieCd', 'audience', 'movieNm', 'nation', 'openDate', 'sales', 'screen','show'))
final = pd.DataFrame(columns=('movieCd', 'audience', 'movieNm', 'nation', 'openDate', 'sales', 'screen','show'))

# %%
# openDate가 공백이 아닌 애만 제외 후 다시 저장
for i in range(0, len(movietemp)):
    if ' ' not in movietemp.iloc[i].openDate:
        tmp = movietemp.iloc[i]
        final = final.append(tmp)

# %%
final.head()
# Out:
#     movieCd audience                movieNm nation    openDate    sales  \
# 0  20180021        1  젊은 아내: 남편 교환의 날 (무삭제)      K  2018-01-22     5000
# 1  20180063      846                     라라      K  2018-02-22  6827500
# 3  20180113      179                 과외의 추억      K  2018-09-07   989000
# 4  20180141      147       정사 : 질투의 덫 - 감독판      K  2018-02-07   808000
# 5  20180142      146           전망 좋은 섹스-감독판      K  2018-01-24   800000
#
#    screen  show
# 0     1.0   1.0
# 1    48.0  53.0
# 3    20.0  21.0
# 4    22.0  22.0
# 5    21.0  21.0

# %%
# 뒤에 빠져있을지 모르니 index 정렬
final = final.reset_index(drop=True)
final
# Out:
#       movieCd audience                movieNm nation    openDate       sales  \
# 110  20189425      173                 발칙한 동거      K  2018-01-15      963000
# 111  20189442      171             아들의 아내 무삭제      K  2018-01-11      905000
# 112  20189523        1            아내를 바꾸다 무삭제      K  2018-01-16        6000
# 113  20189525     9057               젝스키스 에이틴      K  2018-01-18    69957200
# 114  20189624       10   장모의 유혹 - 아내가 집에 없던 날      K  2018-01-10       50000
# 115  20189663    99922                    게이트      K  2018-02-28   821271100
# 116  20189741      146          동창생의 목적 - 감독판      K  2018-01-17      804000
# 117  20189742      129                  사촌 누나      K  2018-03-08      765000
# 118  20189746     5986      극장판 뽀잉: 슈퍼 변신의 비밀      K  2018-09-20    91252000
# 119  20189761      503    터닝메카드W: 반다인의 비밀 특별판      K  2018-02-08    78820700
# 120  20189781        3     정사 : 바람난 유부녀들 무삭제판      K  2018-01-15        6000
# 121  20189783   954070                    챔피언      K  2018-05-01  9471138230
# 122  20189862      120           감금의 시간 2 무삭제      K  2018-01-17      701000
# 123  20189869     7181                 해피 투게더      K  2018-11-15    90207250
# 124  20189902        1      파도 여인 그리고 탱고 무삭제판      K  2018-01-12        5000
#
#       screen     show
# 0        1.0      1.0
# 1       48.0     53.0
# 2       20.0     21.0
# 3       22.0     22.0
# 4       21.0     21.0
# 5       20.0     22.0
# 6     2516.0   8172.0
# 7      601.0   1008.0
# 8       20.0     20.0
# 9       20.0     20.0
# 10      20.0     20.0
# 11   20602.0  88488.0
# 12      19.0     19.0
# 13       1.0      1.0
# 14      20.0     20.0
# 15       3.0      3.0
# 16      20.0     20.0
# 17    3784.0   5266.0
# 18      20.0     20.0
# 19    7696.0  19030.0
# 20      18.0     18.0
# 21      12.0     13.0
# 22       1.0      1.0
# 23      20.0     20.0
# 24    1684.0   2511.0
# 25      19.0     19.0
# 26    1522.0   1925.0
# 27      20.0     20.0
# 28      20.0     20.0
# 29      20.0     20.0
# ..       ...      ...
# 95      36.0     37.0
# 96      20.0     20.0
# 97      20.0     20.0
# 98      20.0     20.0
# 99      20.0     20.0
# 100    403.0    424.0
# 101     20.0     20.0
# 102     19.0     19.0
# 103   2698.0   5646.0
# 104     34.0     39.0
# 105     20.0     20.0
# 106  14321.0  41885.0
# 107      7.0      8.0
# 108      7.0     20.0
# 109     20.0     20.0
# 110     20.0     20.0
# 111     20.0     20.0
# 112      1.0      1.0
# 113    414.0    760.0
# 114      1.0      1.0
# 115   2159.0   5310.0
# 116     21.0     21.0
# 117     20.0     20.0
# 118   2130.0   2452.0
# 119    906.0   1561.0
# 120      3.0      3.0
# 121  12553.0  47356.0
# 122     20.0     20.0
# 123   1645.0   2288.0
# 124      1.0      1.0
#
# [125 rows x 8 columns]

# %%
# 공백값 없음 확인
final[final.openDate == ' ']
# Out:
# Empty DataFrame
# Columns: [movieCd, audience, movieNm, nation, openDate, sales, screen, show]
# Index: []

# %%
final.to_csv("data1.csv", index=False)
