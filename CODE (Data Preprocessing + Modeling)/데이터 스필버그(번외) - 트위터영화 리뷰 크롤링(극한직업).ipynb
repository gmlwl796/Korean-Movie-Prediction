# %%
#from bs4 import BeautifulSoup
import requests
from selenium import webdriver
import time
import datetime as dt
from time import sleep
from datetime import datetime

temptweets = []
startdate = "2019-01-25"
untildate = "2019-01-26"
enddate = "2019-02-01"

#startdate = datetime.strptime(startdate, '%Y-%m-%d')
#untildate = datetime.strptime(untildate, '%Y-%m-%d')
#enddate = datetime.strptime(date, '%Y-%m-%d')

#untildate += dt.timedelta(days=1)
#untildate = datetime.strftime(untildate, '%Y-%m-%d')
#untildate

# Chrome의 경우 | 아까 받은 chromedriver의 위치를 지정해준다.
driver = webdriver.Chrome('C:/Users/student/Downloads/chromedriver_win32/chromedriver.exe')
driver.implicitly_wait(3) # 암묵적으로 웹 자원을 (최대) 3초 기다리기

while not enddate==startdate:
    strtemp = '극한직업'
    driver.get('https://twitter.com/search?q=극한직업%20since%3A'+str(startdate)+'%20until%3A'+str(untildate)+'&amp;amp;amp;amp;amp;amp;lang=eg')
    lastHeight = driver.execute_script("return document.body.scrollHeight")
    
    while True:
        dailyfreq={'Date':startdate}
        all_tweets = driver.find_elements_by_css_selector('.TweetTextSize')
       # for p in all_tweets:
        #    print (p.text)
        #    temptweets.append(p.text)
        
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(1)
        newHeight = driver.execute_script("return document.body.scrollHeight")        
        
        if newHeight != lastHeight:
            all_tweets = driver.find_elements_by_css_selector('.TweetTextSize')
           # for p in all_tweets:
            #    print (p.text)
            #    temptweets.append(p.text)
        else:
            startdate=untildate
            untildate = datetime.strptime(untildate, '%Y-%m-%d')
            untildate+=dt.timedelta(days=1)
            untildate = datetime.strftime(untildate, '%Y-%m-%d')
            for p in all_tweets:
                print (p.text)
                temptweets.append(p.text)
            break
#         i+=1
        lastHeight = newHeight
# Out:
# 친구들이랑 영화보러간당
#
# 극한직업보러간다
# 190123 컬투쇼 극한직업 얍
# #공명 #GONGMYOUNG
# 징짜 극한직업 모두들 꼭 보세요,,
# 진짜 개꿀잼 제발 다들 보세요ㅋㅋㅋㅋㅋㅋ
# 오늘 영화 보러가시는 분들 모두 잘 관람하고 오세요ㅠㅠ 전 내일 이랍니다.  꺅! 오늘은 극한직업 보고 오겟숩니다ㅋㅋ pic.twitter.com/4sM5IldIYw
# ＇극한직업＇ 박스오피스 1위, ＇코미디·1월 영화＇ 역대 최다 오프닝 갱신 https://movie.v.daum.net/v/20190124144910099 …
# 예고편은 수없이 봐도 재밌을거 같던데...함 극장가서 보고싶긴 하당.
# 비엘 작가 극한직업임....
# 극한직업 보러왔어여 ><
# 죽어서 영화 살리는 남자 류승룡, 좀비 마약반장으로 화려하게 부활!
#
# 지난 23일(수) 개봉한 영화 <극한직업>, 개봉 첫 날부터 박스오피스 1위를 차지하며 개봉 3일 만인 26일(금) 누적 관객 1백만명 돌파 예상.
#
# https://blog.naver.com/cinemaplus/221450579716 … pic.twitter.com/nXFGPcDrni
# [soul.g_heo] 190125
#
# 극한직업 선희  많이 사랑해주세요 #극한직업#선희#장진희#사랑해
#
# https://www.instagram.com/p/BtDAUICngby/?utm_source=ig_share_sheet&igshid=81t6rs3y5trx … pic.twitter.com/scyXVXM08k
# 극한직업 : 코로코로 기어 콘테스트 관계자들
# ‘극한직업’ 개봉 3일 만에 100만 돌파…박스오피스 1위 ‘굳건’
# 어쩌다 보니 벌써 2차 극한직업 재밌어용 맹이횽 짱귀여워 ㅋㅋㅋㅋㅋ
# 극한직업 어때
# 이번 주말에 보러가자 친구야 +_+
#
# #극한직업 #류승룡 #이하늬 #공명 #진선규 #이동휘 http://dispatch.co.kr/2002591
# 극한직업 보고 왔는데 공띵 기엽네ㅠㅠ
# ...

# %%
temptweets
# Out:
# ['친구들이랑 영화보러간당\n\n극한직업보러간다',
#  '190123 컬투쇼 극한직업 얍\n#공명 #GONGMYOUNG',
#  '징짜 극한직업 모두들 꼭 보세요,,\n진짜 개꿀잼 제발 다들 보세요ㅋㅋㅋㅋㅋㅋ',
#  '오늘 영화 보러가시는 분들 모두 잘 관람하고 오세요ㅠㅠ 전 내일 이랍니다.  꺅! 오늘은 극한직업 보고 오겟숩니다ㅋㅋ pic.twitter.com/4sM5IldIYw',
#  '＇극한직업＇ 박스오피스 1위, ＇코미디·1월 영화＇ 역대 최다 오프닝 갱신 https://movie.v.daum.net/v/20190124144910099 …\n예고편은 수없이 봐도 재밌을거 같던데...함 극장가서 보고싶긴 하당.',
#  '비엘 작가 극한직업임....',
#  '극한직업 보러왔어여 ><',
#  '죽어서 영화 살리는 남자 류승룡, 좀비 마약반장으로 화려하게 부활!\n\n지난 23일(수) 개봉한 영화 <극한직업>, 개봉 첫 날부터 박스오피스 1위를 차지하며 개봉 3일 만인 26일(금) 누적 관객 1백만명 돌파 예상.\n\nhttps://blog.naver.com/cinemaplus/221450579716 … pic.twitter.com/nXFGPcDrni',
#  '[soul.g_heo] 190125\n\n극한직업 선희  많이 사랑해주세요 #극한직업#선희#장진희#사랑해\n\nhttps://www.instagram.com/p/BtDAUICngby/?utm_source=ig_share_sheet&igshid=81t6rs3y5trx … pic.twitter.com/scyXVXM08k',
#  '극한직업 : 코로코로 기어 콘테스트 관계자들 ',
#  '‘극한직업’ 개봉 3일 만에 100만 돌파…박스오피스 1위 ‘굳건’ ',
#  '어쩌다 보니 벌써 2차 극한직업 재밌어용 맹이횽 짱귀여워 ㅋㅋㅋㅋㅋ ',
#  '극한직업 어때',
# ...

# %%
import pandas as pd
temptweets = pd.DataFrame(temptweets)

# %%
temptweets.to_csv('./csv2/review_tweets_hardjob.csv')

# %%
#from bs4 import BeautifulSoup
import requests
from selenium import webdriver
import time
import datetime as dt
from time import sleep
from datetime import datetime

temptweets = []
startdate = "2019-01-25"
untildate = "2019-01-26"
enddate = "2019-02-01"

#startdate = datetime.strptime(startdate, '%Y-%m-%d')
#untildate = datetime.strptime(untildate, '%Y-%m-%d')
#enddate = datetime.strptime(date, '%Y-%m-%d')

#untildate += dt.timedelta(days=1)
#untildate = datetime.strftime(untildate, '%Y-%m-%d')
#untildate

# Chrome의 경우 | 아까 받은 chromedriver의 위치를 지정해준다.
driver = webdriver.Chrome('C:/Users/student/Downloads/chromedriver_win32/chromedriver.exe')
driver.implicitly_wait(3) # 암묵적으로 웹 자원을 (최대) 3초 기다리기

while not enddate==startdate:
    strtemp = '극한직업'
    driver.get('https://twitter.com/search?q=영화 극한직업%20since%3A'+str(startdate)+'%20until%3A'+str(untildate)+'&amp;amp;amp;amp;amp;amp;lang=eg')
    lastHeight = driver.execute_script("return document.body.scrollHeight")
    
    while True:
        dailyfreq={'Date':startdate}
        all_tweets = driver.find_elements_by_css_selector('.TweetTextSize')
       # for p in all_tweets:
        #    print (p.text)
        #    temptweets.append(p.text)
        
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(1)
        newHeight = driver.execute_script("return document.body.scrollHeight")        
        
        if newHeight != lastHeight:
            all_tweets = driver.find_elements_by_css_selector('.TweetTextSize')
           # for p in all_tweets:
            #    print (p.text)
            #    temptweets.append(p.text)
        else:
            startdate=untildate
            untildate = datetime.strptime(untildate, '%Y-%m-%d')
            untildate+=dt.timedelta(days=1)
            untildate = datetime.strftime(untildate, '%Y-%m-%d')
            for p in all_tweets:
                print (p.text)
                temptweets.append(p.text)
            break
#         i+=1
        lastHeight = newHeight
# Out:
# 친구들이랑 영화보러간당
#
# 극한직업보러간다
# 극한직업 영화본 사람만 아는 대사
# 췈헠칰, 가자아~!!!!!!!! ,안아파..^^안아파...^^
# 오늘 영화 보러가시는 분들 모두 잘 관람하고 오세요ㅠㅠ 전 내일 이랍니다.  꺅! 오늘은 극한직업 보고 오겟숩니다ㅋㅋ pic.twitter.com/4sM5IldIYw
# ＇극한직업＇ 박스오피스 1위, ＇코미디·1월 영화＇ 역대 최다 오프닝 갱신 https://movie.v.daum.net/v/20190124144910099 …
# 예고편은 수없이 봐도 재밌을거 같던데...함 극장가서 보고싶긴 하당.
# 극한직업 영화 재밌나요???
# 영화보러간다~~~극한직업이였나?
# 영화 극한직업 보고 왔당
# 죽어서 영화 살리는 남자 류승룡, 좀비 마약반장으로 화려하게 부활!
#
# 지난 23일(수) 개봉한 영화 <극한직업>, 개봉 첫 날부터 박스오피스 1위를 차지하며 개봉 3일 만인 26일(금) 누적 관객 1백만명 돌파 예상.
#
# https://blog.naver.com/cinemaplus/221450579716 … pic.twitter.com/nXFGPcDrni
# 나중에 영화보려는데 뭘 볼까..
# 극한직업 볼까
# “콜라 뿜을 뻔했다” 개봉하자마자 박스오피스 1위 찍은 핵웃긴 영화 '극한직업' https://www.insight.co.kr/news/206531
# 영화보고 나왔는데 피자들고 집에 들어온 사람 느낌되었구.... 암튼 극한직업 재밌었어 우리애도 코미디 찍었으면ㅜㅜ
# 급 영화관람ㅋ
# #극한직업
# 배꼽빠지는줄 ㅋㅋ
# 선규오빠 knuababoda96 도 나오고 지영언니 @velvety74 도 나오고 반가웠어요~^^
# 너무웃김 ㅋㅋ seoul, South Korea https://www.instagram.com/p/BtDkXUNh2ns/?utm_source=ig_twitter_share&igshid=uhocb2usqz21 …
# 영화보구 옵니다 극한직업
# ...

# %%
temptweets
# Out:
# ['친구들이랑 영화보러간당\n\n극한직업보러간다',
#  '극한직업 영화본 사람만 아는 대사\n췈헠칰, 가자아~!!!!!!!! ,안아파..^^안아파...^^',
#  '오늘 영화 보러가시는 분들 모두 잘 관람하고 오세요ㅠㅠ 전 내일 이랍니다.  꺅! 오늘은 극한직업 보고 오겟숩니다ㅋㅋ pic.twitter.com/4sM5IldIYw',
#  '＇극한직업＇ 박스오피스 1위, ＇코미디·1월 영화＇ 역대 최다 오프닝 갱신 https://movie.v.daum.net/v/20190124144910099 …\n예고편은 수없이 봐도 재밌을거 같던데...함 극장가서 보고싶긴 하당.',
#  '극한직업 영화 재밌나요???',
#  '영화보러간다~~~극한직업이였나?',
#  '영화 극한직업 보고 왔당',
#  '죽어서 영화 살리는 남자 류승룡, 좀비 마약반장으로 화려하게 부활!\n\n지난 23일(수) 개봉한 영화 <극한직업>, 개봉 첫 날부터 박스오피스 1위를 차지하며 개봉 3일 만인 26일(금) 누적 관객 1백만명 돌파 예상.\n\nhttps://blog.naver.com/cinemaplus/221450579716 … pic.twitter.com/nXFGPcDrni',
#  '나중에 영화보려는데 뭘 볼까..\n극한직업 볼까',
#  "“콜라 뿜을 뻔했다” 개봉하자마자 박스오피스 1위 찍은 핵웃긴 영화 '극한직업' https://www.insight.co.kr/news/206531 ",
#  '영화보고 나왔는데 피자들고 집에 들어온 사람 느낌되었구.... 암튼 극한직업 재밌었어 우리애도 코미디 찍었으면ㅜㅜ',
# ...

# %%
import pandas as pd
temptweets = pd.DataFrame(temptweets)

# %%
temptweets.to_csv('./csv2/review_tweets_hardjob2.csv')

# %%
#from bs4 import BeautifulSoup
import requests
from selenium import webdriver
import time
import datetime as dt
from time import sleep

tempnews = []
for i in range(0,1):
    startdate = "2016-02-15"
    untildate = "2016-02-16"
    enddate = "2016-02-17"
    
    # Chrome의 경우 | 아까 받은 chromedriver의 위치를 지정해준다.
    driver = webdriver.Chrome('C:/Users/gmlwl/Downloads/chromedriver_win32/chromedriver.exe')
    driver.implicitly_wait(3) # 암묵적으로 웹 자원을 (최대) 3초 기다리기

    strtemp = '영화 명량'
    driver.get('https://twitter.com/search?q=명량%20since%3A'+str(startdate)+'%20until%3A'+str(untildate)+'&amp;amp;amp;amp;amp;amp;lang=eg')
#    html = driver.page_source
#    soup=BeautifulSoup(html,'html.parser')
    
    lastHeight = driver.execute_script("return document.body.scrollHeight")
    
    dailyfreq={'Date':startdate}
#     i=0 i는 페이지수
    wordfreq=0
    #tweets = driver.find_element_by_class_name('TweetTextSize')
    #tweets = driver.find_elements_by_xpath("[@class='TweetTextSize']")
    #tweets=soup.find_all("p", {"class": "TweetTextSize"})
    #print(tweets.text)
    all_tweets = driver.find_elements_by_css_selector('.TweetTextSize')
    for p in all_tweets:
        print (p.text)
